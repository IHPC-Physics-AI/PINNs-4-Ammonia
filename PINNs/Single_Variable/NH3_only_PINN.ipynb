# %% [markdown]
# ## Overview

# %%
#This code seeks to build a PINN that returns the concentration of gases and temperature across discretized points in an ammonia cracking reactor.

"""
This is achieved in the following steps:

  1. Import a PDE solver for the CDRS Equation for Ammonia Cracking and use it to solve for the concentration of gases and temperature across discretized points in times t.
  2. Outline the structure of an NN and initialise random parameters.
  3. Construct Pseudoinverse Matrix Ax = b and obtain x.
  4. Obtain fitness of NN by computing Data Loss and Physics Loss
  5. Recalibrate Parameters
"""
# Out:
# '\nThis is achieved in the following steps:\n\n  1. Import a PDE solver for the CDRS Equation for Ammonia Cracking and use it to solve for the concentration of gases and temperature across discretized points in times t.\n  2. Outline the structure of an NN and initialise random parameters.\n  3. Construct Pseudoinverse Matrix Ax = b and obtain x.\n  4. Obtain fitness of NN by computing Data Loss and Physics Loss\n  5. Recalibrate Parameters\n'

# %% [markdown]
# ## Imports

# %%
from Compiled_helper_functions import *
# Out:
# Mounted at /content/drive

# %%
import jax
import flax
import optax
from jax import lax, random, numpy as jnp
from jax import random, grad, vmap, hessian, jacfwd, jit
from jax import config
from flax import linen as nn
from jax.scipy.linalg import solve

import time
import numpy as np
import matplotlib.pyplot as plt

# choose GPU
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
jax.config.update("jax_enable_x64", True)

get_ipython().system('pip install evojax')
from evojax.util import get_params_format_fn
# Out:
# Requirement already satisfied: evojax in /usr/local/lib/python3.11/dist-packages (0.2.17)
# Requirement already satisfied: flax in /usr/local/lib/python3.11/dist-packages (from evojax) (0.10.6)
# Requirement already satisfied: jax>=0.2.17 in /usr/local/lib/python3.11/dist-packages (from evojax) (0.5.3)
# Requirement already satisfied: jaxlib>=0.1.65 in /usr/local/lib/python3.11/dist-packages (from evojax) (0.5.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from evojax) (11.3.0)
# Requirement already satisfied: cma in /usr/local/lib/python3.11/dist-packages (from evojax) (4.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from evojax) (3.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from evojax) (6.0.2)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.2.17->evojax) (0.5.3)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.11/dist-packages (from jax>=0.2.17->evojax) (2.0.2)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax>=0.2.17->evojax) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax>=0.2.17->evojax) (1.16.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.11/dist-packages (from flax->evojax) (1.1.1)
# Requirement already satisfied: optax in /usr/local/lib/python3.11/dist-packages (from flax->evojax) (0.2.5)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.11/dist-packages (from flax->evojax) (0.11.20)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.11/dist-packages (from flax->evojax) (0.1.76)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.11/dist-packages (from flax->evojax) (13.9.4)
# Requirement already satisfied: typing_extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from flax->evojax) (4.14.1)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.11/dist-packages (from flax->evojax) (0.1.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->evojax) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->evojax) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->evojax) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->evojax) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->evojax) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->evojax) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->evojax) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->evojax) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax->evojax) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax->evojax) (2.19.2)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from optax->flax->evojax) (1.4.0)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.11/dist-packages (from optax->flax->evojax) (0.1.90)
# Requirement already satisfied: etils[epath,epy] in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax->evojax) (1.13.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax->evojax) (1.6.0)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax->evojax) (24.1.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax->evojax) (5.29.5)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax->evojax) (4.12.3)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax->evojax) (3.20.1)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chex>=0.1.87->optax->flax->evojax) (0.12.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax->evojax) (0.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->evojax) (2025.3.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->evojax) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->evojax) (3.23.0)

# %%
jax.config.update("jax_enable_x64", True)
jax.config.update("jax_debug_nans", True)

# %% [markdown]
# ## Import Steady State Solution

# %%
# Import Solution
y_steady = np.load('steady_state_sol.npy')

# Create Class Objects
reac = Reac()
oper = Oper(reac)

# %%
# NH3 and T_x sol
y_steady_reshaped = y_steady.reshape(reac.Ns + 1, reac.Nx, order ='C')
y_shortened = y_steady_reshaped
Y_NH3 = y_shortened[0]
T_x = y_shortened[-1]

sol = y_shortened.reshape(1,-1, order = 'C')
print(y_shortened)
print(Y_NH3)
# Out:
# [[9.95000000e-01 9.94694363e-01 9.94404470e-01 ... 9.07179510e-01
#   9.07126571e-01 9.07094143e-01]
#  [2.50000000e-03 2.95845494e-03 3.39329442e-03 ... 1.34230734e-01
#   1.34310143e-01 1.34358786e-01]
#  [2.50000000e-03 2.65281831e-03 2.79776481e-03 ... 4.64102448e-02
#   4.64367143e-02 4.64529287e-02]
#  [8.04568806e-21 8.04568806e-21 8.04568806e-21 ... 8.04568846e-21
#   8.04568846e-21 8.04568847e-21]
#  [7.71500000e+02 7.71698166e+02 7.71785597e+02 ... 7.72750784e+02
#   7.72750853e+02 7.72750899e+02]]
# [0.995      0.99469436 0.99440447 ... 0.90717951 0.90712657 0.90709414]

# %% [markdown]
# ## Outline Structure of NN and Initialise Random Parameters

# %%
# PINN

n_l = 4
class PINN(nn.Module):
    """PINNs"""
    def setup(self):
      #single hidden layer
        self.layers = [nn.Dense(n_nodes, kernel_init = jax.nn.initializers.he_uniform(), use_bias=True),
                        jnp.sin,
                       nn.Dense(n_nodes, kernel_init = jax.nn.initializers.he_uniform(), use_bias=True),
                       nn.swish,
                       nn.Dense(n_nodes, kernel_init = jax.nn.initializers.he_uniform(), use_bias=True),
                       nn.tanh,
                       nn.Dense(n_nodes, kernel_init = jax.nn.initializers.he_uniform(), use_bias=True),
                       jnp.exp
                       ]
        #self.last_layer = nn.Dense(1, kernel_init = jax.nn.initializers.he_uniform(), use_bias=False)


    @nn.compact
    def __call__(self, inputs):
        # split the two variables, probably just by slicing
        # t = inputs
        x = inputs
        def get_u(x):
            # f = t / 10 - 0.4
            f = x
            fs = []
            for i, lyr in enumerate(self.layers):
                f = lyr(f)
                """For sin activation"""
                if (i == 0):
                    pre_act = f
                    f = 2*jnp.pi*f #first hidden layer mult by 2pi
                if (i%2 != 0):
                    fs.append(f)
            fs = jnp.hstack(fs) #stop at the hidden layer before output
            #u = self.last_layer(f)
            return f, pre_act, fs

        f, pre_act, fs = get_u(x)

        # obtain f_t
        def get_f_dir(get_u, x):
            # f_t = jacfwd(get_u)(t)  # much faster (10x) than u_xx, f_xx = hessian(get_u)(x, y)
            f_x = jacfwd(lambda x: get_u(x)[0])(x)  # much faster (10x) than u_xx, f_xx = hessian(get_u)(x, y)
            f_xx = jacfwd(jacfwd(lambda x: get_u(x)[0]))(x)

            f_x = jnp.squeeze(f_x, axis= -1)
            f_xx = jnp.squeeze(f_xx, axis= (-1,-2))
            print(f_xx.shape)
            return f_xx, f_x

        f_dir_vmap = vmap(get_f_dir, in_axes=(None, 0))
        f_xx, f_x = f_dir_vmap(get_u, x)


        outputs = jnp.hstack([f, f_x, f_xx])

        return outputs, pre_act

# %%
# choose seed
seed = 10
key, rng = random.split(random.PRNGKey(seed))

# dummy input
a = random.normal(key, [1, 1]) #only for x

# initialization call
n_nodes = 256
# n_nodes = 350
# n_nodes = 128
# n_nodes = 64
model = PINN()
params = model.init(key, a)
num_params, format_params_fn = get_params_format_fn(params)

# flatten initial params
params = jax.flatten_util.ravel_pytree(params)[0]

# for inverst problem - append params to include 2 more parameters
key, rng = random.split(rng) # update random generator
# ini_a = random.normal(key, [1, n_e + 1]) #one for lmbda, other for lambda
ini_a = random.normal(key, [1, 1]) #one for lmbda, other for lambda
params = jnp.append(params, ini_a)
print(ini_a)
# Out:
# (256,)
# [[0.27489732]]

# %% [markdown]
# ## Evaluating PDE Constants

# %%
def regularization_factor(params):
  reg = 10**(nn.tanh(params)*5)

  return reg

# %%
def eval_loss(params):

  # Apply Model
  shaped_xvals = reac.xvals.reshape(reac.Nx, 1)
  #jax.debug.print("shaped_xvals {x}", x=shaped_xvals)
  pred, pre_act = model.apply(format_params_fn(params[:-1]), shaped_xvals)
  f, f_x, f_xx = jnp.split(pred, 3, axis=1)
  #print("f", f.shape)
  #print("f_x", f_x.shape)
  #print("f_xx", f_xx.shape)

  # Initial Guess of NH3 and T
  """
  Random Generation
  key1, key2, rng = jax.random.split(key, 3)
  Y_NH3 = jax.random.normal(key1, [1, reac.Nx])
  T_x = jax.random.normal(key2, [1, reac.Nx])
  """


  coeffs = gen_coeffs(y_steady, reac, oper)
  coeffs = coeffs
  #jax.debug.print("coeffs: {c}", c= coeffs.T)

  # Generate Matrix A

  pde_A1 = coeffs[:,0].reshape(-1,1) * f_xx + coeffs[:,1].reshape(-1,1) * f_x
  bc_NH3_A = f[0]
  bc2_NH3_A = f_x[-1]
  A = jnp.vstack([pde_A1, bc_NH3_A, bc2_NH3_A])

  # Generate RHS

  reg = regularization_factor(params[-1]) #10**(nn.sigmoid(params[-1])*4 - 6)
  #jax.debug.print("reg: {r}", r = reg)

  # Generate RHS
  pde_b1 = -coeffs[:,2].reshape(-1,1)
  b = jnp.vstack([pde_b1, jnp.array(0.995), jnp.array(0.0)])
  #jax.debug.print("b: {b}", b = b)

  As, bs = reg*jnp.eye(A.shape[1]) + (A.T@A), A.T@b #this is least squares  (A.T@A)
  w_PI = solve(As, bs)
  #jax.debug.print("W: {w}", w= w_PI)

  """
  jax.debug.print("f, {f}", f = f)
  jax.debug.print("f_x, {f}", f = f_x)
  jax.debug.print("f_xx, {f}", f = f_xx)
  """

  pred1 = f @ w_PI
  #jax.debug.print("Pred1 = {w}", w= pred1)
  #pred2 = f @ w_PI[1*n_nodes:2*n_nodes, :]
  #pred_all = jnp.hstack([pred1, pred2])


  pde_residual = A @ w_PI
  pde_residual = pde_residual.reshape(reac.Nx + 2, 1) # CHANGED FOR 1 VARIABLE
  pde_right = b.reshape(reac.Nx + 2,1) # CHANGED FOR 1 VARIABLE
  pde_loss = jnp.mean(jnp.square(pde_residual - pde_right))


  # ssr, mse, rl2
  ssr = jnp.sum((b - A @ w_PI)**2)
  # mse = jnp.mean(jnp.square(gt_solver - pred_all))
  #mse = jnp.sum(jnp.mean(jnp.square(sol - pred_all), axis=0))
  #mse = jnp.sum(jnp.mean(jnp.square(Y_NH3 - pred1), axis=0))

  #max_gt = jnp.max(gt_solver, axis=0)
  #rl2 = jnp.sum(jnp.linalg.norm(gt_solver - pred_all, axis=0)/max_gt)

  rl2_A = jnp.linalg.norm(Y_NH3.reshape(-1, 1) - pred1) / jnp.linalg.norm(Y_NH3.reshape(-1, 1))

  loss = rl2_A + pde_loss

  return loss, (ssr, rl2_A, pde_loss)

loss_grad = jax.jit(jax.value_and_grad(eval_loss, has_aux=True))
# loss_grad = jax.value_and_grad(eval_loss, has_aux=True)



# weights update
@jit
def update(params, opt_state):
    (loss, (ssr, rl2, pde_loss)), grad0 = loss_grad(params)
    return loss, ssr, rl2, pde_loss, grad0

@jit
def update1(params, opt_state, grads):
    updates, opt_state = optimizer.update(grads, opt_state)
    params = optax.apply_updates(params, updates)
    return params, opt_state

# %%
# optimizer
max_iters = 500
# max_iters = 200
max_lr = 1e-4


lr_scheduler = optax.warmup_cosine_decay_schedule(init_value=max_lr, peak_value=max_lr, warmup_steps=int(max_iters*.2),
                                                  decay_steps=max_iters, end_value=1e-6)
#lr_scheduler = optax.cosine_decay_schedule(init_value=max_lr, decay_steps=max_iters * 2)


optimizer = optax.adam(learning_rate=lr_scheduler) # Choose the method
# optimizer = optax.adam(learning_rate=0.001) # Choose the method
opt_state = optimizer.init(params)


# training iteration
runtime = 0
train_iters = 0

store = []
para_all = {}

rl2_best = 1e10
while (train_iters <= max_iters):
    # mini-batch updater
    # key, rng = random.split(rng) # update random generator
    # if (train_iters % 20 == 0):
    #     para_all[train_iters] = params
    para_all[train_iters] = params

    losses, ssrs, rl2s, pde_losses, grads = 0, 0, 0, 0, 0
    loss, ssr, rl2, pde_loss, grad0 = update(params, opt_state)
    grads = grads + grad0
    losses = losses + loss
    ssrs = ssrs + ssr
    rl2s = rl2s + rl2
    pde_losses = pde_losses + pde_loss
    params, opt_state = update1(params, opt_state, grads)

    if jnp.isnan(losses).any() or jnp.isnan(grads).any():
      print(f"NaN detected at iteration {train_iters}. Stopping training.")
      break




    # append weights
    if (train_iters % 1 == 0):
        reg = regularization_factor(params[-1]) #10**(nn.sigmoid(params[-1])*4 - 6)
        print ('iter. = %05d,  time = %03ds,  loss = %.4e,  ssr = %.4e,  rl2s = %.4e, pde = %.4e,reg = %.4e'%(train_iters, runtime, losses, ssrs, rl2s, pde_losses, reg))
        store.append([train_iters, runtime, losses, ssrs, pde_losses, rl2s])

    if rl2s < rl2_best:
        rl2s_best = rl2s
        jnp.save('best_0', para_all[train_iters])

    train_iters += 1

store = jnp.array(store)
# Out:
# (256,)
# iter. = 00000,  time = 000s,  loss = 1.4080e-01,  ssr = 2.4128e-02,  rl2s = 1.4078e-01, pde = 2.4056e-05,reg = 2.1899e+01
# iter. = 00001,  time = 000s,  loss = 1.3052e-01,  ssr = 2.0811e-02,  rl2s = 1.3050e-01, pde = 2.0749e-05,reg = 2.1875e+01
# iter. = 00002,  time = 000s,  loss = 1.2357e-01,  ssr = 1.8825e-02,  rl2s = 1.2355e-01, pde = 1.8769e-05,reg = 2.1852e+01
# iter. = 00003,  time = 000s,  loss = 1.1816e-01,  ssr = 1.7436e-02,  rl2s = 1.1814e-01, pde = 1.7384e-05,reg = 2.1829e+01
# iter. = 00004,  time = 000s,  loss = 1.1362e-01,  ssr = 1.6357e-02,  rl2s = 1.1361e-01, pde = 1.6308e-05,reg = 2.1806e+01
# iter. = 00005,  time = 000s,  loss = 1.0977e-01,  ssr = 1.5488e-02,  rl2s = 1.0976e-01, pde = 1.5442e-05,reg = 2.1783e+01
# iter. = 00006,  time = 000s,  loss = 1.0652e-01,  ssr = 1.4793e-02,  rl2s = 1.0650e-01, pde = 1.4749e-05,reg = 2.1760e+01
# iter. = 00007,  time = 000s,  loss = 1.0375e-01,  ssr = 1.4244e-02,  rl2s = 1.0374e-01, pde = 1.4201e-05,reg = 2.1737e+01
# iter. = 00008,  time = 000s,  loss = 1.0137e-01,  ssr = 1.3806e-02,  rl2s = 1.0135e-01, pde = 1.3765e-05,reg = 2.1714e+01
# iter. = 00009,  time = 000s,  loss = 9.9254e-02,  ssr = 1.3447e-02,  rl2s = 9.9241e-02, pde = 1.3407e-05,reg = 2.1692e+01
# iter. = 00010,  time = 000s,  loss = 9.7337e-02,  ssr = 1.3144e-02,  rl2s = 9.7324e-02, pde = 1.3105e-05,reg = 2.1670e+01
# iter. = 00011,  time = 000s,  loss = 9.5569e-02,  ssr = 1.2878e-02,  rl2s = 9.5556e-02, pde = 1.2839e-05,reg = 2.1647e+01
# iter. = 00012,  time = 000s,  loss = 9.3911e-02,  ssr = 1.2631e-02,  rl2s = 9.3899e-02, pde = 1.2594e-05,reg = 2.1625e+01
# iter. = 00013,  time = 000s,  loss = 9.2333e-02,  ssr = 1.2392e-02,  rl2s = 9.2321e-02, pde = 1.2355e-05,reg = 2.1603e+01
# iter. = 00014,  time = 000s,  loss = 9.0826e-02,  ssr = 1.2158e-02,  rl2s = 9.0814e-02, pde = 1.2121e-05,reg = 2.1581e+01
# iter. = 00015,  time = 000s,  loss = 8.9402e-02,  ssr = 1.1937e-02,  rl2s = 8.9390e-02, pde = 1.1902e-05,reg = 2.1559e+01
# iter. = 00016,  time = 000s,  loss = 8.8073e-02,  ssr = 1.1739e-02,  rl2s = 8.8061e-02, pde = 1.1704e-05,reg = 2.1538e+01
# iter. = 00017,  time = 000s,  loss = 8.6836e-02,  ssr = 1.1565e-02,  rl2s = 8.6824e-02, pde = 1.1530e-05,reg = 2.1516e+01
# iter. = 00018,  time = 000s,  loss = 8.5676e-02,  ssr = 1.1408e-02,  rl2s = 8.5665e-02, pde = 1.1374e-05,reg = 2.1495e+01
# iter. = 00019,  time = 000s,  loss = 8.4584e-02,  ssr = 1.1264e-02,  rl2s = 8.4572e-02, pde = 1.1231e-05,reg = 2.1473e+01
# iter. = 00020,  time = 000s,  loss = 8.3562e-02,  ssr = 1.1135e-02,  rl2s = 8.3551e-02, pde = 1.1102e-05,reg = 2.1452e+01
# iter. = 00021,  time = 000s,  loss = 8.2617e-02,  ssr = 1.1021e-02,  rl2s = 8.2606e-02, pde = 1.0988e-05,reg = 2.1431e+01
# iter. = 00022,  time = 000s,  loss = 8.1740e-02,  ssr = 1.0920e-02,  rl2s = 8.1729e-02, pde = 1.0888e-05,reg = 2.1410e+01
# iter. = 00023,  time = 000s,  loss = 8.0912e-02,  ssr = 1.0826e-02,  rl2s = 8.0901e-02, pde = 1.0793e-05,reg = 2.1389e+01
# iter. = 00024,  time = 000s,  loss = 8.0117e-02,  ssr = 1.0733e-02,  rl2s = 8.0106e-02, pde = 1.0700e-05,reg = 2.1368e+01
# iter. = 00025,  time = 000s,  loss = 7.9358e-02,  ssr = 1.0643e-02,  rl2s = 7.9348e-02, pde = 1.0611e-05,reg = 2.1347e+01
# iter. = 00026,  time = 000s,  loss = 7.8643e-02,  ssr = 1.0564e-02,  rl2s = 7.8632e-02, pde = 1.0532e-05,reg = 2.1327e+01
# iter. = 00027,  time = 000s,  loss = 7.7967e-02,  ssr = 1.0497e-02,  rl2s = 7.7957e-02, pde = 1.0466e-05,reg = 2.1306e+01
# iter. = 00028,  time = 000s,  loss = 7.7317e-02,  ssr = 1.0438e-02,  rl2s = 7.7307e-02, pde = 1.0407e-05,reg = 2.1286e+01
# iter. = 00029,  time = 000s,  loss = 7.6683e-02,  ssr = 1.0382e-02,  rl2s = 7.6673e-02, pde = 1.0351e-05,reg = 2.1265e+01
# iter. = 00030,  time = 000s,  loss = 7.6065e-02,  ssr = 1.0325e-02,  rl2s = 7.6055e-02, pde = 1.0294e-05,reg = 2.1245e+01
# iter. = 00031,  time = 000s,  loss = 7.5466e-02,  ssr = 1.0268e-02,  rl2s = 7.5456e-02, pde = 1.0238e-05,reg = 2.1225e+01
# iter. = 00032,  time = 000s,  loss = 7.4882e-02,  ssr = 1.0212e-02,  rl2s = 7.4871e-02, pde = 1.0182e-05,reg = 2.1205e+01
# iter. = 00033,  time = 000s,  loss = 7.4306e-02,  ssr = 1.0158e-02,  rl2s = 7.4296e-02, pde = 1.0128e-05,reg = 2.1185e+01
# iter. = 00034,  time = 000s,  loss = 7.3742e-02,  ssr = 1.0111e-02,  rl2s = 7.3732e-02, pde = 1.0081e-05,reg = 2.1165e+01
# iter. = 00035,  time = 000s,  loss = 7.3193e-02,  ssr = 1.0077e-02,  rl2s = 7.3183e-02, pde = 1.0047e-05,reg = 2.1145e+01
# iter. = 00036,  time = 000s,  loss = 7.2653e-02,  ssr = 1.0057e-02,  rl2s = 7.2643e-02, pde = 1.0027e-05,reg = 2.1125e+01
# iter. = 00037,  time = 000s,  loss = 7.2109e-02,  ssr = 1.0049e-02,  rl2s = 7.2099e-02, pde = 1.0019e-05,reg = 2.1106e+01
# iter. = 00038,  time = 000s,  loss = 7.1555e-02,  ssr = 1.0050e-02,  rl2s = 7.1545e-02, pde = 1.0020e-05,reg = 2.1086e+01
# iter. = 00039,  time = 000s,  loss = 7.0987e-02,  ssr = 1.0057e-02,  rl2s = 7.0977e-02, pde = 1.0027e-05,reg = 2.1067e+01
# iter. = 00040,  time = 000s,  loss = 7.0395e-02,  ssr = 1.0064e-02,  rl2s = 7.0385e-02, pde = 1.0034e-05,reg = 2.1047e+01
# iter. = 00041,  time = 000s,  loss = 6.9768e-02,  ssr = 1.0070e-02,  rl2s = 6.9758e-02, pde = 1.0040e-05,reg = 2.1028e+01
# iter. = 00042,  time = 000s,  loss = 6.9100e-02,  ssr = 1.0086e-02,  rl2s = 6.9090e-02, pde = 1.0056e-05,reg = 2.1008e+01
# iter. = 00043,  time = 000s,  loss = 6.8380e-02,  ssr = 1.0128e-02,  rl2s = 6.8370e-02, pde = 1.0098e-05,reg = 2.0989e+01
# iter. = 00044,  time = 000s,  loss = 6.7590e-02,  ssr = 1.0209e-02,  rl2s = 6.7580e-02, pde = 1.0178e-05,reg = 2.0970e+01
# iter. = 00045,  time = 000s,  loss = 6.6710e-02,  ssr = 1.0329e-02,  rl2s = 6.6700e-02, pde = 1.0298e-05,reg = 2.0951e+01
# iter. = 00046,  time = 000s,  loss = 6.5712e-02,  ssr = 1.0476e-02,  rl2s = 6.5701e-02, pde = 1.0445e-05,reg = 2.0932e+01
# iter. = 00047,  time = 000s,  loss = 6.4560e-02,  ssr = 1.0638e-02,  rl2s = 6.4549e-02, pde = 1.0606e-05,reg = 2.0913e+01
# iter. = 00048,  time = 000s,  loss = 6.3212e-02,  ssr = 1.0841e-02,  rl2s = 6.3201e-02, pde = 1.0809e-05,reg = 2.0894e+01
# iter. = 00049,  time = 000s,  loss = 6.1604e-02,  ssr = 1.1165e-02,  rl2s = 6.1593e-02, pde = 1.1132e-05,reg = 2.0876e+01
# iter. = 00050,  time = 000s,  loss = 5.9630e-02,  ssr = 1.1689e-02,  rl2s = 5.9619e-02, pde = 1.1654e-05,reg = 2.0857e+01
# iter. = 00051,  time = 000s,  loss = 5.7144e-02,  ssr = 1.2419e-02,  rl2s = 5.7132e-02, pde = 1.2382e-05,reg = 2.0839e+01
# iter. = 00052,  time = 000s,  loss = 5.3951e-02,  ssr = 1.3353e-02,  rl2s = 5.3937e-02, pde = 1.3313e-05,reg = 2.0820e+01
# iter. = 00053,  time = 000s,  loss = 4.9720e-02,  ssr = 1.4838e-02,  rl2s = 4.9706e-02, pde = 1.4794e-05,reg = 2.0802e+01
# iter. = 00054,  time = 000s,  loss = 4.3767e-02,  ssr = 1.7710e-02,  rl2s = 4.3749e-02, pde = 1.7657e-05,reg = 2.0784e+01
# iter. = 00055,  time = 000s,  loss = 3.4947e-02,  ssr = 2.2718e-02,  rl2s = 3.4924e-02, pde = 2.2650e-05,reg = 2.0767e+01
# iter. = 00056,  time = 000s,  loss = 2.1959e-02,  ssr = 3.0441e-02,  rl2s = 2.1928e-02, pde = 3.0350e-05,reg = 2.0750e+01
# iter. = 00057,  time = 000s,  loss = 6.4719e-03,  ssr = 4.1260e-02,  rl2s = 6.4308e-03, pde = 4.1136e-05,reg = 2.0733e+01
# iter. = 00058,  time = 000s,  loss = 1.7098e-02,  ssr = 2.5642e-02,  rl2s = 1.7073e-02, pde = 2.5566e-05,reg = 2.0716e+01
# iter. = 00059,  time = 000s,  loss = 2.4808e-02,  ssr = 6.2702e-02,  rl2s = 2.4746e-02, pde = 6.2515e-05,reg = 2.0703e+01
# iter. = 00060,  time = 000s,  loss = 4.7968e-02,  ssr = 1.0692e-02,  rl2s = 4.7957e-02, pde = 1.0660e-05,reg = 2.0689e+01
# iter. = 00061,  time = 000s,  loss = 5.8490e-02,  ssr = 8.8474e-03,  rl2s = 5.8481e-02, pde = 8.8210e-06,reg = 2.0675e+01
# iter. = 00062,  time = 000s,  loss = 6.1686e-02,  ssr = 8.5813e-03,  rl2s = 6.1677e-02, pde = 8.5556e-06,reg = 2.0660e+01
# iter. = 00063,  time = 000s,  loss = 6.3007e-02,  ssr = 8.4933e-03,  rl2s = 6.2999e-02, pde = 8.4679e-06,reg = 2.0645e+01
# iter. = 00064,  time = 000s,  loss = 6.3569e-02,  ssr = 8.4392e-03,  rl2s = 6.3561e-02, pde = 8.4140e-06,reg = 2.0630e+01
# iter. = 00065,  time = 000s,  loss = 6.3732e-02,  ssr = 8.3933e-03,  rl2s = 6.3723e-02, pde = 8.3682e-06,reg = 2.0615e+01
# iter. = 00066,  time = 000s,  loss = 6.3639e-02,  ssr = 8.3522e-03,  rl2s = 6.3631e-02, pde = 8.3273e-06,reg = 2.0599e+01
# iter. = 00067,  time = 000s,  loss = 6.3358e-02,  ssr = 8.3195e-03,  rl2s = 6.3350e-02, pde = 8.2946e-06,reg = 2.0583e+01
# iter. = 00068,  time = 000s,  loss = 6.2923e-02,  ssr = 8.3018e-03,  rl2s = 6.2915e-02, pde = 8.2770e-06,reg = 2.0567e+01
# iter. = 00069,  time = 000s,  loss = 6.2356e-02,  ssr = 8.3081e-03,  rl2s = 6.2348e-02, pde = 8.2833e-06,reg = 2.0550e+01
# iter. = 00070,  time = 000s,  loss = 6.1668e-02,  ssr = 8.3473e-03,  rl2s = 6.1659e-02, pde = 8.3223e-06,reg = 2.0534e+01
# iter. = 00071,  time = 000s,  loss = 6.0856e-02,  ssr = 8.4269e-03,  rl2s = 6.0848e-02, pde = 8.4017e-06,reg = 2.0517e+01
# iter. = 00072,  time = 000s,  loss = 5.9904e-02,  ssr = 8.5528e-03,  rl2s = 5.9896e-02, pde = 8.5273e-06,reg = 2.0500e+01
# iter. = 00073,  time = 000s,  loss = 5.8778e-02,  ssr = 8.7313e-03,  rl2s = 5.8769e-02, pde = 8.7052e-06,reg = 2.0484e+01
# iter. = 00074,  time = 000s,  loss = 5.7429e-02,  ssr = 8.9711e-03,  rl2s = 5.7420e-02, pde = 8.9443e-06,reg = 2.0467e+01
# iter. = 00075,  time = 000s,  loss = 5.5797e-02,  ssr = 9.2874e-03,  rl2s = 5.5788e-02, pde = 9.2596e-06,reg = 2.0450e+01
# iter. = 00076,  time = 000s,  loss = 5.3807e-02,  ssr = 9.7041e-03,  rl2s = 5.3797e-02, pde = 9.6751e-06,reg = 2.0433e+01
# iter. = 00077,  time = 000s,  loss = 5.1365e-02,  ssr = 1.0259e-02,  rl2s = 5.1354e-02, pde = 1.0229e-05,reg = 2.0416e+01
# iter. = 00078,  time = 000s,  loss = 4.8350e-02,  ssr = 1.1014e-02,  rl2s = 4.8339e-02, pde = 1.0981e-05,reg = 2.0400e+01
# iter. = 00079,  time = 000s,  loss = 4.4611e-02,  ssr = 1.2072e-02,  rl2s = 4.4599e-02, pde = 1.2036e-05,reg = 2.0383e+01
# iter. = 00080,  time = 000s,  loss = 3.9946e-02,  ssr = 1.3621e-02,  rl2s = 3.9933e-02, pde = 1.3580e-05,reg = 2.0367e+01
# iter. = 00081,  time = 000s,  loss = 3.4010e-02,  ssr = 1.6042e-02,  rl2s = 3.3994e-02, pde = 1.5994e-05,reg = 2.0351e+01
# iter. = 00082,  time = 000s,  loss = 2.5992e-02,  ssr = 2.0211e-02,  rl2s = 2.5972e-02, pde = 2.0151e-05,reg = 2.0335e+01
# iter. = 00083,  time = 000s,  loss = 1.4468e-02,  ssr = 2.7898e-02,  rl2s = 1.4440e-02, pde = 2.7815e-05,reg = 2.0320e+01
# iter. = 00084,  time = 000s,  loss = 5.5763e-04,  ssr = 4.0141e-02,  rl2s = 5.1761e-04, pde = 4.0021e-05,reg = 2.0307e+01
# iter. = 00085,  time = 000s,  loss = 8.3096e-03,  ssr = 3.2298e-02,  rl2s = 8.2774e-03, pde = 3.2202e-05,reg = 2.0295e+01
# iter. = 00086,  time = 000s,  loss = 4.6299e-03,  ssr = 3.4243e-02,  rl2s = 4.5957e-03, pde = 3.4140e-05,reg = 2.0282e+01
# iter. = 00087,  time = 000s,  loss = 1.0963e-02,  ssr = 4.7489e-02,  rl2s = 1.0916e-02, pde = 4.7347e-05,reg = 2.0272e+01
# iter. = 00088,  time = 000s,  loss = 2.5649e-03,  ssr = 3.3627e-02,  rl2s = 2.5314e-03, pde = 3.3526e-05,reg = 2.0262e+01
# iter. = 00089,  time = 000s,  loss = 5.4182e-03,  ssr = 4.1047e-02,  rl2s = 5.3772e-03, pde = 4.0925e-05,reg = 2.0254e+01
# iter. = 00090,  time = 000s,  loss = 8.9555e-03,  ssr = 2.9460e-02,  rl2s = 8.9262e-03, pde = 2.9372e-05,reg = 2.0245e+01
# iter. = 00091,  time = 000s,  loss = 7.6142e-03,  ssr = 3.0258e-02,  rl2s = 7.5841e-03, pde = 3.0168e-05,reg = 2.0237e+01
# iter. = 00092,  time = 000s,  loss = 5.2064e-03,  ssr = 4.0171e-02,  rl2s = 5.1664e-03, pde = 4.0051e-05,reg = 2.0230e+01
# iter. = 00093,  time = 000s,  loss = 3.0418e-04,  ssr = 3.5263e-02,  rl2s = 2.6903e-04, pde = 3.5158e-05,reg = 2.0224e+01
# iter. = 00094,  time = 000s,  loss = 1.6299e-02,  ssr = 2.2814e-02,  rl2s = 1.6276e-02, pde = 2.2746e-05,reg = 2.0219e+01
# iter. = 00095,  time = 000s,  loss = 1.9968e-02,  ssr = 2.0985e-02,  rl2s = 1.9948e-02, pde = 2.0922e-05,reg = 2.0212e+01
# iter. = 00096,  time = 000s,  loss = 1.6319e-02,  ssr = 2.3875e-02,  rl2s = 1.6295e-02, pde = 2.3803e-05,reg = 2.0205e+01
# iter. = 00097,  time = 000s,  loss = 8.1490e-03,  ssr = 3.0780e-02,  rl2s = 8.1183e-03, pde = 3.0688e-05,reg = 2.0198e+01
# iter. = 00098,  time = 000s,  loss = 3.8865e-03,  ssr = 4.1719e-02,  rl2s = 3.8449e-03, pde = 4.1594e-05,reg = 2.0193e+01
# iter. = 00099,  time = 000s,  loss = 5.7600e-03,  ssr = 3.6449e-02,  rl2s = 5.7236e-03, pde = 3.6340e-05,reg = 2.0187e+01
# iter. = 00100,  time = 000s,  loss = 1.7748e-03,  ssr = 4.1319e-02,  rl2s = 1.7336e-03, pde = 4.1195e-05,reg = 2.0182e+01
# iter. = 00101,  time = 000s,  loss = 1.4180e-02,  ssr = 2.9256e-02,  rl2s = 1.4151e-02, pde = 2.9168e-05,reg = 2.0177e+01
# iter. = 00102,  time = 000s,  loss = 1.1105e-02,  ssr = 3.0011e-02,  rl2s = 1.1075e-02, pde = 2.9922e-05,reg = 2.0171e+01
# iter. = 00103,  time = 000s,  loss = 9.4606e-03,  ssr = 4.3010e-02,  rl2s = 9.4177e-03, pde = 4.2881e-05,reg = 2.0167e+01
# iter. = 00104,  time = 000s,  loss = 4.1293e-03,  ssr = 3.4974e-02,  rl2s = 4.0945e-03, pde = 3.4870e-05,reg = 2.0164e+01
# iter. = 00105,  time = 000s,  loss = 1.7688e-02,  ssr = 1.8913e-02,  rl2s = 1.7670e-02, pde = 1.8857e-05,reg = 2.0161e+01
# iter. = 00106,  time = 000s,  loss = 2.2844e-02,  ssr = 1.6348e-02,  rl2s = 2.2827e-02, pde = 1.6300e-05,reg = 2.0156e+01
# iter. = 00107,  time = 000s,  loss = 1.9042e-02,  ssr = 1.8525e-02,  rl2s = 1.9023e-02, pde = 1.8470e-05,reg = 2.0151e+01
# iter. = 00108,  time = 000s,  loss = 6.9122e-03,  ssr = 2.6954e-02,  rl2s = 6.8853e-03, pde = 2.6874e-05,reg = 2.0145e+01
# iter. = 00109,  time = 000s,  loss = 1.1947e-02,  ssr = 4.5802e-02,  rl2s = 1.1901e-02, pde = 4.5665e-05,reg = 2.0141e+01
# iter. = 00110,  time = 000s,  loss = 4.2214e-03,  ssr = 4.4195e-02,  rl2s = 4.1774e-03, pde = 4.4063e-05,reg = 2.0139e+01
# iter. = 00111,  time = 000s,  loss = 2.2504e-02,  ssr = 2.7085e-02,  rl2s = 2.2477e-02, pde = 2.7004e-05,reg = 2.0135e+01
# iter. = 00112,  time = 000s,  loss = 3.1251e-02,  ssr = 2.1755e-02,  rl2s = 3.1230e-02, pde = 2.1690e-05,reg = 2.0131e+01
# iter. = 00113,  time = 000s,  loss = 3.2260e-02,  ssr = 2.0269e-02,  rl2s = 3.2240e-02, pde = 2.0209e-05,reg = 2.0125e+01
# iter. = 00114,  time = 000s,  loss = 2.8650e-02,  ssr = 2.0623e-02,  rl2s = 2.8629e-02, pde = 2.0562e-05,reg = 2.0118e+01
# iter. = 00115,  time = 000s,  loss = 2.0823e-02,  ssr = 2.2733e-02,  rl2s = 2.0800e-02, pde = 2.2665e-05,reg = 2.0111e+01
# iter. = 00116,  time = 000s,  loss = 8.7370e-03,  ssr = 2.7069e-02,  rl2s = 8.7100e-03, pde = 2.6988e-05,reg = 2.0104e+01
# iter. = 00117,  time = 000s,  loss = 4.6469e-03,  ssr = 3.2679e-02,  rl2s = 4.6144e-03, pde = 3.2582e-05,reg = 2.0098e+01
# iter. = 00118,  time = 000s,  loss = 6.8787e-03,  ssr = 2.1425e-02,  rl2s = 6.8574e-03, pde = 2.1361e-05,reg = 2.0091e+01
# iter. = 00119,  time = 000s,  loss = 9.3682e-03,  ssr = 1.9550e-02,  rl2s = 9.3487e-03, pde = 1.9491e-05,reg = 2.0085e+01
# iter. = 00120,  time = 000s,  loss = 1.6744e-04,  ssr = 2.5737e-02,  rl2s = 1.4178e-04, pde = 2.5660e-05,reg = 2.0079e+01
# iter. = 00121,  time = 000s,  loss = 8.1610e-03,  ssr = 2.0833e-02,  rl2s = 8.1402e-03, pde = 2.0770e-05,reg = 2.0074e+01
# iter. = 00122,  time = 000s,  loss = 3.1435e-03,  ssr = 2.4604e-02,  rl2s = 3.1190e-03, pde = 2.4530e-05,reg = 2.0068e+01
# iter. = 00123,  time = 000s,  loss = 1.5609e-02,  ssr = 4.1594e-02,  rl2s = 1.5568e-02, pde = 4.1470e-05,reg = 2.0063e+01
# iter. = 00124,  time = 000s,  loss = 1.0275e-02,  ssr = 4.0302e-02,  rl2s = 1.0235e-02, pde = 4.0181e-05,reg = 2.0060e+01
# iter. = 00125,  time = 000s,  loss = 1.2645e-02,  ssr = 2.5056e-02,  rl2s = 1.2620e-02, pde = 2.4982e-05,reg = 2.0056e+01
# iter. = 00126,  time = 000s,  loss = 1.9230e-02,  ssr = 2.1770e-02,  rl2s = 1.9208e-02, pde = 2.1705e-05,reg = 2.0051e+01
# iter. = 00127,  time = 000s,  loss = 1.6680e-02,  ssr = 2.3529e-02,  rl2s = 1.6656e-02, pde = 2.3459e-05,reg = 2.0046e+01
# iter. = 00128,  time = 000s,  loss = 4.7049e-03,  ssr = 3.1534e-02,  rl2s = 4.6734e-03, pde = 3.1439e-05,reg = 2.0040e+01
# iter. = 00129,  time = 000s,  loss = 2.0416e-02,  ssr = 5.2676e-02,  rl2s = 2.0363e-02, pde = 5.2518e-05,reg = 2.0036e+01
# iter. = 00130,  time = 000s,  loss = 2.2226e-02,  ssr = 5.3072e-02,  rl2s = 2.2173e-02, pde = 5.2914e-05,reg = 2.0033e+01
# iter. = 00131,  time = 000s,  loss = 4.9460e-03,  ssr = 3.5942e-02,  rl2s = 4.9102e-03, pde = 3.5834e-05,reg = 2.0032e+01
# iter. = 00132,  time = 000s,  loss = 1.9857e-02,  ssr = 1.9165e-02,  rl2s = 1.9838e-02, pde = 1.9108e-05,reg = 2.0029e+01
# iter. = 00133,  time = 000s,  loss = 2.9283e-02,  ssr = 1.5189e-02,  rl2s = 2.9268e-02, pde = 1.5144e-05,reg = 2.0025e+01
# iter. = 00134,  time = 000s,  loss = 3.2303e-02,  ssr = 1.4413e-02,  rl2s = 3.2289e-02, pde = 1.4370e-05,reg = 2.0021e+01
# iter. = 00135,  time = 000s,  loss = 3.1841e-02,  ssr = 1.5100e-02,  rl2s = 3.1826e-02, pde = 1.5055e-05,reg = 2.0015e+01
# iter. = 00136,  time = 000s,  loss = 2.8682e-02,  ssr = 1.7208e-02,  rl2s = 2.8665e-02, pde = 1.7157e-05,reg = 2.0008e+01
# iter. = 00137,  time = 000s,  loss = 2.2791e-02,  ssr = 2.1490e-02,  rl2s = 2.2769e-02, pde = 2.1426e-05,reg = 2.0001e+01
# iter. = 00138,  time = 000s,  loss = 1.4008e-02,  ssr = 2.9341e-02,  rl2s = 1.3979e-02, pde = 2.9253e-05,reg = 1.9993e+01
# iter. = 00139,  time = 000s,  loss = 3.3182e-03,  ssr = 4.1424e-02,  rl2s = 3.2769e-03, pde = 4.1300e-05,reg = 1.9985e+01
# iter. = 00140,  time = 000s,  loss = 6.2346e-03,  ssr = 5.3830e-02,  rl2s = 6.1810e-03, pde = 5.3669e-05,reg = 1.9978e+01
# iter. = 00141,  time = 000s,  loss = 6.2403e-04,  ssr = 5.0227e-02,  rl2s = 5.7395e-04, pde = 5.0077e-05,reg = 1.9971e+01
# iter. = 00142,  time = 000s,  loss = 2.4322e-03,  ssr = 4.7925e-02,  rl2s = 2.3845e-03, pde = 4.7782e-05,reg = 1.9964e+01
# iter. = 00143,  time = 000s,  loss = 4.5954e-03,  ssr = 5.1998e-02,  rl2s = 4.5435e-03, pde = 5.1842e-05,reg = 1.9958e+01
# iter. = 00144,  time = 000s,  loss = 2.3059e-03,  ssr = 4.3942e-02,  rl2s = 2.2621e-03, pde = 4.3810e-05,reg = 1.9952e+01
# iter. = 00145,  time = 000s,  loss = 1.3572e-03,  ssr = 4.4614e-02,  rl2s = 1.3127e-03, pde = 4.4480e-05,reg = 1.9947e+01
# iter. = 00146,  time = 000s,  loss = 6.9800e-03,  ssr = 3.5949e-02,  rl2s = 6.9442e-03, pde = 3.5841e-05,reg = 1.9942e+01
# iter. = 00147,  time = 000s,  loss = 5.5750e-03,  ssr = 3.5240e-02,  rl2s = 5.5399e-03, pde = 3.5134e-05,reg = 1.9936e+01
# iter. = 00148,  time = 000s,  loss = 4.4053e-03,  ssr = 4.1058e-02,  rl2s = 4.3644e-03, pde = 4.0935e-05,reg = 1.9932e+01
# iter. = 00149,  time = 000s,  loss = 2.3307e-03,  ssr = 3.6994e-02,  rl2s = 2.2938e-03, pde = 3.6883e-05,reg = 1.9929e+01
# iter. = 00150,  time = 000s,  loss = 8.7554e-03,  ssr = 2.7106e-02,  rl2s = 8.7283e-03, pde = 2.7025e-05,reg = 1.9926e+01
# iter. = 00151,  time = 000s,  loss = 1.1035e-02,  ssr = 2.4738e-02,  rl2s = 1.1010e-02, pde = 2.4664e-05,reg = 1.9922e+01
# iter. = 00152,  time = 000s,  loss = 6.8274e-03,  ssr = 2.6932e-02,  rl2s = 6.8006e-03, pde = 2.6852e-05,reg = 1.9917e+01
# iter. = 00153,  time = 000s,  loss = 4.4264e-03,  ssr = 3.4855e-02,  rl2s = 4.3917e-03, pde = 3.4751e-05,reg = 1.9913e+01
# iter. = 00154,  time = 000s,  loss = 5.6490e-03,  ssr = 3.5045e-02,  rl2s = 5.6140e-03, pde = 3.4940e-05,reg = 1.9911e+01
# iter. = 00155,  time = 000s,  loss = 1.9679e-03,  ssr = 2.8365e-02,  rl2s = 1.9396e-03, pde = 2.8280e-05,reg = 1.9908e+01
# iter. = 00156,  time = 000s,  loss = 1.5151e-03,  ssr = 2.8442e-02,  rl2s = 1.4867e-03, pde = 2.8357e-05,reg = 1.9905e+01
# iter. = 00157,  time = 000s,  loss = 5.9662e-03,  ssr = 3.4338e-02,  rl2s = 5.9320e-03, pde = 3.4235e-05,reg = 1.9902e+01
# iter. = 00158,  time = 000s,  loss = 4.5986e-03,  ssr = 3.3129e-02,  rl2s = 4.5656e-03, pde = 3.3029e-05,reg = 1.9901e+01
# iter. = 00159,  time = 000s,  loss = 3.9065e-03,  ssr = 2.6551e-02,  rl2s = 3.8800e-03, pde = 2.6472e-05,reg = 1.9899e+01
# iter. = 00160,  time = 000s,  loss = 5.0137e-03,  ssr = 2.5912e-02,  rl2s = 4.9878e-03, pde = 2.5834e-05,reg = 1.9897e+01
# iter. = 00161,  time = 000s,  loss = 2.3346e-04,  ssr = 2.9763e-02,  rl2s = 2.0379e-04, pde = 2.9674e-05,reg = 1.9893e+01
# iter. = 00162,  time = 000s,  loss = 1.0566e-02,  ssr = 3.9460e-02,  rl2s = 1.0527e-02, pde = 3.9342e-05,reg = 1.9891e+01
# iter. = 00163,  time = 000s,  loss = 1.2650e-02,  ssr = 4.2530e-02,  rl2s = 1.2607e-02, pde = 4.2403e-05,reg = 1.9890e+01
# iter. = 00164,  time = 000s,  loss = 6.9722e-03,  ssr = 3.8735e-02,  rl2s = 6.9336e-03, pde = 3.8619e-05,reg = 1.9890e+01
# iter. = 00165,  time = 000s,  loss = 3.9048e-03,  ssr = 3.1201e-02,  rl2s = 3.8736e-03, pde = 3.1107e-05,reg = 1.9889e+01
# iter. = 00166,  time = 000s,  loss = 7.7703e-03,  ssr = 2.8793e-02,  rl2s = 7.7416e-03, pde = 2.8707e-05,reg = 1.9887e+01
# iter. = 00167,  time = 000s,  loss = 6.7970e-03,  ssr = 2.9448e-02,  rl2s = 6.7676e-03, pde = 2.9360e-05,reg = 1.9884e+01
# iter. = 00168,  time = 000s,  loss = 1.6520e-03,  ssr = 3.2864e-02,  rl2s = 1.6193e-03, pde = 3.2766e-05,reg = 1.9881e+01
# iter. = 00169,  time = 000s,  loss = 7.8278e-03,  ssr = 3.9764e-02,  rl2s = 7.7882e-03, pde = 3.9645e-05,reg = 1.9878e+01
# iter. = 00170,  time = 000s,  loss = 1.0498e-02,  ssr = 4.1217e-02,  rl2s = 1.0457e-02, pde = 4.1094e-05,reg = 1.9877e+01
# iter. = 00171,  time = 000s,  loss = 6.6916e-03,  ssr = 3.6885e-02,  rl2s = 6.6548e-03, pde = 3.6775e-05,reg = 1.9878e+01
# iter. = 00172,  time = 000s,  loss = 2.5033e-03,  ssr = 2.8687e-02,  rl2s = 2.4747e-03, pde = 2.8601e-05,reg = 1.9877e+01
# iter. = 00173,  time = 000s,  loss = 5.2699e-03,  ssr = 2.6745e-02,  rl2s = 5.2432e-03, pde = 2.6665e-05,reg = 1.9875e+01
# iter. = 00174,  time = 000s,  loss = 2.9176e-03,  ssr = 2.9134e-02,  rl2s = 2.8885e-03, pde = 2.9047e-05,reg = 1.9872e+01
# iter. = 00175,  time = 000s,  loss = 3.4535e-03,  ssr = 3.5708e-02,  rl2s = 3.4179e-03, pde = 3.5602e-05,reg = 1.9871e+01
# iter. = 00176,  time = 000s,  loss = 4.1160e-03,  ssr = 3.7565e-02,  rl2s = 4.0785e-03, pde = 3.7453e-05,reg = 1.9871e+01
# iter. = 00177,  time = 000s,  loss = 3.8938e-04,  ssr = 3.5275e-02,  rl2s = 3.5421e-04, pde = 3.5169e-05,reg = 1.9872e+01
# iter. = 00178,  time = 000s,  loss = 6.4678e-03,  ssr = 3.0407e-02,  rl2s = 6.4375e-03, pde = 3.0316e-05,reg = 1.9872e+01
# iter. = 00179,  time = 000s,  loss = 9.1046e-03,  ssr = 2.8952e-02,  rl2s = 9.0757e-03, pde = 2.8865e-05,reg = 1.9870e+01
# iter. = 00180,  time = 000s,  loss = 8.5137e-03,  ssr = 2.9910e-02,  rl2s = 8.4839e-03, pde = 2.9821e-05,reg = 1.9867e+01
# iter. = 00181,  time = 000s,  loss = 5.2205e-03,  ssr = 3.2999e-02,  rl2s = 5.1876e-03, pde = 3.2900e-05,reg = 1.9864e+01
# iter. = 00182,  time = 000s,  loss = 5.3365e-04,  ssr = 3.8265e-02,  rl2s = 4.9550e-04, pde = 3.8151e-05,reg = 1.9862e+01
# iter. = 00183,  time = 000s,  loss = 2.2498e-03,  ssr = 4.0488e-02,  rl2s = 2.2095e-03, pde = 4.0367e-05,reg = 1.9861e+01
# iter. = 00184,  time = 000s,  loss = 2.4328e-04,  ssr = 3.9557e-02,  rl2s = 2.0384e-04, pde = 3.9438e-05,reg = 1.9862e+01
# iter. = 00185,  time = 000s,  loss = 5.0361e-03,  ssr = 3.6009e-02,  rl2s = 5.0002e-03, pde = 3.5901e-05,reg = 1.9862e+01
# iter. = 00186,  time = 000s,  loss = 6.5233e-03,  ssr = 3.5182e-02,  rl2s = 6.4882e-03, pde = 3.5077e-05,reg = 1.9860e+01
# iter. = 00187,  time = 000s,  loss = 4.6645e-03,  ssr = 3.6788e-02,  rl2s = 4.6278e-03, pde = 3.6678e-05,reg = 1.9857e+01
# iter. = 00188,  time = 000s,  loss = 9.8283e-05,  ssr = 4.0462e-02,  rl2s = 5.7942e-05, pde = 4.0341e-05,reg = 1.9853e+01
# iter. = 00189,  time = 000s,  loss = 4.6971e-03,  ssr = 4.4166e-02,  rl2s = 4.6531e-03, pde = 4.4034e-05,reg = 1.9852e+01
# iter. = 00190,  time = 000s,  loss = 5.3632e-03,  ssr = 4.4451e-02,  rl2s = 5.3188e-03, pde = 4.4319e-05,reg = 1.9852e+01
# iter. = 00191,  time = 000s,  loss = 2.3216e-03,  ssr = 4.1439e-02,  rl2s = 2.2803e-03, pde = 4.1315e-05,reg = 1.9853e+01
# iter. = 00192,  time = 000s,  loss = 4.3861e-03,  ssr = 3.5443e-02,  rl2s = 4.3507e-03, pde = 3.5337e-05,reg = 1.9853e+01
# iter. = 00193,  time = 000s,  loss = 6.7230e-03,  ssr = 3.3475e-02,  rl2s = 6.6896e-03, pde = 3.3375e-05,reg = 1.9852e+01
# iter. = 00194,  time = 000s,  loss = 5.1618e-03,  ssr = 3.4898e-02,  rl2s = 5.1270e-03, pde = 3.4794e-05,reg = 1.9849e+01
# iter. = 00195,  time = 000s,  loss = 7.3102e-04,  ssr = 3.8993e-02,  rl2s = 6.9214e-04, pde = 3.8877e-05,reg = 1.9845e+01
# iter. = 00196,  time = 000s,  loss = 4.9850e-03,  ssr = 4.4443e-02,  rl2s = 4.9407e-03, pde = 4.4310e-05,reg = 1.9843e+01
# iter. = 00197,  time = 000s,  loss = 5.6023e-03,  ssr = 4.5014e-02,  rl2s = 5.5574e-03, pde = 4.4879e-05,reg = 1.9843e+01
# iter. = 00198,  time = 000s,  loss = 9.9173e-04,  ssr = 4.0326e-02,  rl2s = 9.5152e-04, pde = 4.0205e-05,reg = 1.9844e+01
# iter. = 00199,  time = 000s,  loss = 9.3813e-03,  ssr = 3.0921e-02,  rl2s = 9.3505e-03, pde = 3.0828e-05,reg = 1.9843e+01
# iter. = 00200,  time = 000s,  loss = 1.3569e-02,  ssr = 2.7731e-02,  rl2s = 1.3541e-02, pde = 2.7648e-05,reg = 1.9842e+01
# iter. = 00201,  time = 000s,  loss = 1.2336e-02,  ssr = 2.9036e-02,  rl2s = 1.2307e-02, pde = 2.8949e-05,reg = 1.9839e+01
# iter. = 00202,  time = 000s,  loss = 6.4181e-03,  ssr = 3.4622e-02,  rl2s = 6.3836e-03, pde = 3.4519e-05,reg = 1.9835e+01
# iter. = 00203,  time = 000s,  loss = 2.7967e-03,  ssr = 4.4312e-02,  rl2s = 2.7525e-03, pde = 4.4180e-05,reg = 1.9832e+01
# iter. = 00204,  time = 000s,  loss = 5.4853e-03,  ssr = 4.8351e-02,  rl2s = 5.4371e-03, pde = 4.8207e-05,reg = 1.9832e+01
# iter. = 00205,  time = 000s,  loss = 4.0893e-03,  ssr = 4.8548e-02,  rl2s = 4.0409e-03, pde = 4.8403e-05,reg = 1.9833e+01
# iter. = 00206,  time = 000s,  loss = 2.5045e-04,  ssr = 4.6336e-02,  rl2s = 2.0425e-04, pde = 4.6197e-05,reg = 1.9832e+01
# iter. = 00207,  time = 000s,  loss = 2.0474e-03,  ssr = 4.5123e-02,  rl2s = 2.0024e-03, pde = 4.4988e-05,reg = 1.9830e+01
# iter. = 00208,  time = 000s,  loss = 1.2484e-03,  ssr = 4.5289e-02,  rl2s = 1.2032e-03, pde = 4.5154e-05,reg = 1.9827e+01
# iter. = 00209,  time = 000s,  loss = 1.8624e-03,  ssr = 4.6672e-02,  rl2s = 1.8158e-03, pde = 4.6533e-05,reg = 1.9826e+01
# iter. = 00210,  time = 000s,  loss = 2.1628e-03,  ssr = 4.6170e-02,  rl2s = 2.1168e-03, pde = 4.6032e-05,reg = 1.9826e+01
# iter. = 00211,  time = 000s,  loss = 1.9367e-04,  ssr = 4.4018e-02,  rl2s = 1.4979e-04, pde = 4.3886e-05,reg = 1.9828e+01
# iter. = 00212,  time = 000s,  loss = 3.7862e-03,  ssr = 4.0436e-02,  rl2s = 3.7459e-03, pde = 4.0315e-05,reg = 1.9827e+01
# iter. = 00213,  time = 000s,  loss = 4.9767e-03,  ssr = 3.9201e-02,  rl2s = 4.9376e-03, pde = 3.9084e-05,reg = 1.9826e+01
# iter. = 00214,  time = 000s,  loss = 3.8725e-03,  ssr = 3.9940e-02,  rl2s = 3.8327e-03, pde = 3.9821e-05,reg = 1.9823e+01
# iter. = 00215,  time = 000s,  loss = 1.0938e-03,  ssr = 4.2130e-02,  rl2s = 1.0518e-03, pde = 4.2004e-05,reg = 1.9819e+01
# iter. = 00216,  time = 000s,  loss = 2.7688e-03,  ssr = 4.5187e-02,  rl2s = 2.7238e-03, pde = 4.5052e-05,reg = 1.9817e+01
# iter. = 00217,  time = 000s,  loss = 3.7025e-03,  ssr = 4.5436e-02,  rl2s = 3.6572e-03, pde = 4.5300e-05,reg = 1.9817e+01
# iter. = 00218,  time = 000s,  loss = 1.7597e-03,  ssr = 4.2707e-02,  rl2s = 1.7171e-03, pde = 4.2579e-05,reg = 1.9818e+01
# iter. = 00219,  time = 000s,  loss = 3.5428e-03,  ssr = 3.6781e-02,  rl2s = 3.5061e-03, pde = 3.6671e-05,reg = 1.9817e+01
# iter. = 00220,  time = 000s,  loss = 5.3818e-03,  ssr = 3.4932e-02,  rl2s = 5.3470e-03, pde = 3.4827e-05,reg = 1.9816e+01
# iter. = 00221,  time = 000s,  loss = 3.5808e-03,  ssr = 3.6992e-02,  rl2s = 3.5439e-03, pde = 3.6882e-05,reg = 1.9813e+01
# iter. = 00222,  time = 000s,  loss = 1.1746e-03,  ssr = 4.2507e-02,  rl2s = 1.1322e-03, pde = 4.2380e-05,reg = 1.9811e+01
# iter. = 00223,  time = 000s,  loss = 2.3060e-03,  ssr = 4.4389e-02,  rl2s = 2.2618e-03, pde = 4.4256e-05,reg = 1.9812e+01
# iter. = 00224,  time = 000s,  loss = 8.5038e-04,  ssr = 4.3453e-02,  rl2s = 8.0705e-04, pde = 4.3323e-05,reg = 1.9813e+01
# iter. = 00225,  time = 000s,  loss = 2.9508e-03,  ssr = 4.0131e-02,  rl2s = 2.9108e-03, pde = 4.0011e-05,reg = 1.9813e+01
# iter. = 00226,  time = 000s,  loss = 3.7387e-03,  ssr = 3.9811e-02,  rl2s = 3.6990e-03, pde = 3.9692e-05,reg = 1.9812e+01
# iter. = 00227,  time = 000s,  loss = 2.1254e-03,  ssr = 4.1906e-02,  rl2s = 2.0836e-03, pde = 4.1781e-05,reg = 1.9809e+01
# iter. = 00228,  time = 000s,  loss = 1.0855e-03,  ssr = 4.5504e-02,  rl2s = 1.0402e-03, pde = 4.5368e-05,reg = 1.9808e+01
# iter. = 00229,  time = 000s,  loss = 1.6808e-03,  ssr = 4.6750e-02,  rl2s = 1.6341e-03, pde = 4.6610e-05,reg = 1.9809e+01
# iter. = 00230,  time = 000s,  loss = 4.3898e-04,  ssr = 4.6420e-02,  rl2s = 3.9270e-04, pde = 4.6282e-05,reg = 1.9811e+01
# iter. = 00231,  time = 000s,  loss = 2.3257e-03,  ssr = 4.5027e-02,  rl2s = 2.2808e-03, pde = 4.4892e-05,reg = 1.9811e+01
# iter. = 00232,  time = 000s,  loss = 3.3594e-03,  ssr = 4.4395e-02,  rl2s = 3.3151e-03, pde = 4.4263e-05,reg = 1.9810e+01
# iter. = 00233,  time = 000s,  loss = 2.8906e-03,  ssr = 4.4495e-02,  rl2s = 2.8462e-03, pde = 4.4362e-05,reg = 1.9808e+01
# iter. = 00234,  time = 000s,  loss = 1.1021e-03,  ssr = 4.5267e-02,  rl2s = 1.0569e-03, pde = 4.5131e-05,reg = 1.9804e+01
# iter. = 00235,  time = 000s,  loss = 1.8971e-03,  ssr = 4.6664e-02,  rl2s = 1.8506e-03, pde = 4.6524e-05,reg = 1.9802e+01
# iter. = 00236,  time = 000s,  loss = 3.0158e-03,  ssr = 4.6678e-02,  rl2s = 2.9692e-03, pde = 4.6539e-05,reg = 1.9802e+01
# iter. = 00237,  time = 000s,  loss = 2.4981e-03,  ssr = 4.5280e-02,  rl2s = 2.4530e-03, pde = 4.5144e-05,reg = 1.9803e+01
# iter. = 00238,  time = 000s,  loss = 4.9686e-04,  ssr = 4.2489e-02,  rl2s = 4.5450e-04, pde = 4.2362e-05,reg = 1.9806e+01
# iter. = 00239,  time = 000s,  loss = 2.9433e-03,  ssr = 3.8401e-02,  rl2s = 2.9050e-03, pde = 3.8286e-05,reg = 1.9806e+01
# iter. = 00240,  time = 000s,  loss = 4.4388e-03,  ssr = 3.6830e-02,  rl2s = 4.4021e-03, pde = 3.6720e-05,reg = 1.9806e+01
# iter. = 00241,  time = 000s,  loss = 4.2250e-03,  ssr = 3.7415e-02,  rl2s = 4.1877e-03, pde = 3.7303e-05,reg = 1.9804e+01
# iter. = 00242,  time = 000s,  loss = 2.6193e-03,  ssr = 3.9812e-02,  rl2s = 2.5796e-03, pde = 3.9693e-05,reg = 1.9801e+01
# iter. = 00243,  time = 000s,  loss = 1.0383e-04,  ssr = 4.3639e-02,  rl2s = 6.0319e-05, pde = 4.3508e-05,reg = 1.9799e+01
# iter. = 00244,  time = 000s,  loss = 1.5352e-03,  ssr = 4.6373e-02,  rl2s = 1.4890e-03, pde = 4.6235e-05,reg = 1.9798e+01
# iter. = 00245,  time = 000s,  loss = 1.4008e-03,  ssr = 4.7672e-02,  rl2s = 1.3532e-03, pde = 4.7530e-05,reg = 1.9799e+01
# iter. = 00246,  time = 000s,  loss = 2.5532e-04,  ssr = 4.7864e-02,  rl2s = 2.0760e-04, pde = 4.7721e-05,reg = 1.9799e+01
# iter. = 00247,  time = 000s,  loss = 5.1009e-04,  ssr = 4.8393e-02,  rl2s = 4.6184e-04, pde = 4.8249e-05,reg = 1.9797e+01
# iter. = 00248,  time = 000s,  loss = 6.9709e-04,  ssr = 4.9305e-02,  rl2s = 6.4794e-04, pde = 4.9158e-05,reg = 1.9797e+01
# iter. = 00249,  time = 000s,  loss = 2.7090e-04,  ssr = 4.9590e-02,  rl2s = 2.2146e-04, pde = 4.9441e-05,reg = 1.9798e+01
# iter. = 00250,  time = 000s,  loss = 1.7536e-03,  ssr = 4.9235e-02,  rl2s = 1.7045e-03, pde = 4.9087e-05,reg = 1.9797e+01
# iter. = 00251,  time = 000s,  loss = 1.8861e-03,  ssr = 4.9254e-02,  rl2s = 1.8370e-03, pde = 4.9106e-05,reg = 1.9796e+01
# iter. = 00252,  time = 000s,  loss = 3.7454e-04,  ssr = 4.9667e-02,  rl2s = 3.2502e-04, pde = 4.9519e-05,reg = 1.9793e+01
# iter. = 00253,  time = 000s,  loss = 2.4664e-03,  ssr = 5.0253e-02,  rl2s = 2.4163e-03, pde = 5.0103e-05,reg = 1.9792e+01
# iter. = 00254,  time = 000s,  loss = 3.3864e-03,  ssr = 4.9943e-02,  rl2s = 3.3366e-03, pde = 4.9793e-05,reg = 1.9792e+01
# iter. = 00255,  time = 000s,  loss = 2.8602e-03,  ssr = 4.8877e-02,  rl2s = 2.8114e-03, pde = 4.8731e-05,reg = 1.9793e+01
# iter. = 00256,  time = 000s,  loss = 1.1624e-03,  ssr = 4.7151e-02,  rl2s = 1.1154e-03, pde = 4.7010e-05,reg = 1.9796e+01
# iter. = 00257,  time = 000s,  loss = 1.5648e-03,  ssr = 4.4876e-02,  rl2s = 1.5201e-03, pde = 4.4741e-05,reg = 1.9797e+01
# iter. = 00258,  time = 000s,  loss = 2.7774e-03,  ssr = 4.3685e-02,  rl2s = 2.7338e-03, pde = 4.3555e-05,reg = 1.9797e+01
# iter. = 00259,  time = 000s,  loss = 2.8041e-03,  ssr = 4.3414e-02,  rl2s = 2.7608e-03, pde = 4.3284e-05,reg = 1.9795e+01
# iter. = 00260,  time = 000s,  loss = 1.8312e-03,  ssr = 4.3933e-02,  rl2s = 1.7874e-03, pde = 4.3802e-05,reg = 1.9793e+01
# iter. = 00261,  time = 000s,  loss = 1.1948e-04,  ssr = 4.5164e-02,  rl2s = 7.4456e-05, pde = 4.5029e-05,reg = 1.9791e+01
# iter. = 00262,  time = 000s,  loss = 9.7785e-04,  ssr = 4.5567e-02,  rl2s = 9.3242e-04, pde = 4.5431e-05,reg = 1.9791e+01
# iter. = 00263,  time = 000s,  loss = 6.7785e-04,  ssr = 4.4913e-02,  rl2s = 6.3307e-04, pde = 4.4779e-05,reg = 1.9792e+01
# iter. = 00264,  time = 000s,  loss = 7.5538e-04,  ssr = 4.3284e-02,  rl2s = 7.1223e-04, pde = 4.3154e-05,reg = 1.9792e+01
# iter. = 00265,  time = 000s,  loss = 9.6464e-04,  ssr = 4.2894e-02,  rl2s = 9.2187e-04, pde = 4.2765e-05,reg = 1.9790e+01
# iter. = 00266,  time = 000s,  loss = 1.4071e-04,  ssr = 4.3666e-02,  rl2s = 9.7180e-05, pde = 4.3535e-05,reg = 1.9788e+01
# iter. = 00267,  time = 000s,  loss = 1.6234e-03,  ssr = 4.5357e-02,  rl2s = 1.5782e-03, pde = 4.5222e-05,reg = 1.9787e+01
# iter. = 00268,  time = 000s,  loss = 2.0441e-03,  ssr = 4.5774e-02,  rl2s = 1.9984e-03, pde = 4.5637e-05,reg = 1.9788e+01
# iter. = 00269,  time = 000s,  loss = 1.3310e-03,  ssr = 4.5018e-02,  rl2s = 1.2861e-03, pde = 4.4884e-05,reg = 1.9789e+01
# iter. = 00270,  time = 000s,  loss = 4.8415e-04,  ssr = 4.3211e-02,  rl2s = 4.4107e-04, pde = 4.3082e-05,reg = 1.9790e+01
# iter. = 00271,  time = 000s,  loss = 9.5259e-04,  ssr = 4.2793e-02,  rl2s = 9.0992e-04, pde = 4.2665e-05,reg = 1.9789e+01
# iter. = 00272,  time = 000s,  loss = 3.1754e-04,  ssr = 4.3597e-02,  rl2s = 2.7408e-04, pde = 4.3467e-05,reg = 1.9787e+01
# iter. = 00273,  time = 000s,  loss = 1.3514e-03,  ssr = 4.5423e-02,  rl2s = 1.3061e-03, pde = 4.5287e-05,reg = 1.9786e+01
# iter. = 00274,  time = 000s,  loss = 1.7150e-03,  ssr = 4.6018e-02,  rl2s = 1.6691e-03, pde = 4.5881e-05,reg = 1.9787e+01
# iter. = 00275,  time = 000s,  loss = 1.0359e-03,  ssr = 4.5575e-02,  rl2s = 9.9042e-04, pde = 4.5439e-05,reg = 1.9788e+01
# iter. = 00276,  time = 000s,  loss = 6.0527e-04,  ssr = 4.4287e-02,  rl2s = 5.6111e-04, pde = 4.4154e-05,reg = 1.9789e+01
# iter. = 00277,  time = 000s,  loss = 1.0598e-03,  ssr = 4.4020e-02,  rl2s = 1.0159e-03, pde = 4.3888e-05,reg = 1.9788e+01
# iter. = 00278,  time = 000s,  loss = 5.8649e-04,  ssr = 4.4605e-02,  rl2s = 5.4202e-04, pde = 4.4472e-05,reg = 1.9786e+01
# iter. = 00279,  time = 000s,  loss = 8.0939e-04,  ssr = 4.5929e-02,  rl2s = 7.6360e-04, pde = 4.5792e-05,reg = 1.9785e+01
# iter. = 00280,  time = 000s,  loss = 1.0687e-03,  ssr = 4.6336e-02,  rl2s = 1.0225e-03, pde = 4.6198e-05,reg = 1.9786e+01
# iter. = 00281,  time = 000s,  loss = 4.0093e-04,  ssr = 4.5943e-02,  rl2s = 3.5512e-04, pde = 4.5806e-05,reg = 1.9788e+01
# iter. = 00282,  time = 000s,  loss = 1.1402e-03,  ssr = 4.4907e-02,  rl2s = 1.0954e-03, pde = 4.4773e-05,reg = 1.9788e+01
# iter. = 00283,  time = 000s,  loss = 1.5936e-03,  ssr = 4.4629e-02,  rl2s = 1.5491e-03, pde = 4.4495e-05,reg = 1.9787e+01
# iter. = 00284,  time = 000s,  loss = 1.1916e-03,  ssr = 4.4989e-02,  rl2s = 1.1468e-03, pde = 4.4854e-05,reg = 1.9786e+01
# iter. = 00285,  time = 000s,  loss = 1.1038e-04,  ssr = 4.5933e-02,  rl2s = 6.4584e-05, pde = 4.5795e-05,reg = 1.9785e+01
# iter. = 00286,  time = 000s,  loss = 6.7161e-04,  ssr = 4.6413e-02,  rl2s = 6.2534e-04, pde = 4.6274e-05,reg = 1.9785e+01
# iter. = 00287,  time = 000s,  loss = 3.5282e-04,  ssr = 4.6193e-02,  rl2s = 3.0676e-04, pde = 4.6055e-05,reg = 1.9786e+01
# iter. = 00288,  time = 000s,  loss = 8.4575e-04,  ssr = 4.5379e-02,  rl2s = 8.0051e-04, pde = 4.5243e-05,reg = 1.9786e+01
# iter. = 00289,  time = 000s,  loss = 1.0214e-03,  ssr = 4.5242e-02,  rl2s = 9.7626e-04, pde = 4.5107e-05,reg = 1.9785e+01
# iter. = 00290,  time = 000s,  loss = 3.8872e-04,  ssr = 4.5697e-02,  rl2s = 3.4316e-04, pde = 4.5560e-05,reg = 1.9783e+01
# iter. = 00291,  time = 000s,  loss = 1.0832e-03,  ssr = 4.6703e-02,  rl2s = 1.0367e-03, pde = 4.6563e-05,reg = 1.9782e+01
# iter. = 00292,  time = 000s,  loss = 1.4960e-03,  ssr = 4.6970e-02,  rl2s = 1.4492e-03, pde = 4.6830e-05,reg = 1.9783e+01
# iter. = 00293,  time = 000s,  loss = 1.0359e-03,  ssr = 4.6554e-02,  rl2s = 9.8950e-04, pde = 4.6415e-05,reg = 1.9784e+01
# iter. = 00294,  time = 000s,  loss = 2.7209e-04,  ssr = 4.5555e-02,  rl2s = 2.2667e-04, pde = 4.5418e-05,reg = 1.9784e+01
# iter. = 00295,  time = 000s,  loss = 5.8364e-04,  ssr = 4.5262e-02,  rl2s = 5.3851e-04, pde = 4.5127e-05,reg = 1.9784e+01
# iter. = 00296,  time = 000s,  loss = 1.2528e-04,  ssr = 4.5597e-02,  rl2s = 7.9818e-05, pde = 4.5460e-05,reg = 1.9782e+01
# iter. = 00297,  time = 000s,  loss = 9.9682e-04,  ssr = 4.6358e-02,  rl2s = 9.5060e-04, pde = 4.6220e-05,reg = 1.9782e+01
# iter. = 00298,  time = 000s,  loss = 1.1210e-03,  ssr = 4.6398e-02,  rl2s = 1.0748e-03, pde = 4.6259e-05,reg = 1.9783e+01
# iter. = 00299,  time = 000s,  loss = 4.5699e-04,  ssr = 4.5786e-02,  rl2s = 4.1134e-04, pde = 4.5649e-05,reg = 1.9784e+01
# iter. = 00300,  time = 000s,  loss = 9.6545e-04,  ssr = 4.4628e-02,  rl2s = 9.2096e-04, pde = 4.4494e-05,reg = 1.9785e+01
# iter. = 00301,  time = 000s,  loss = 1.4185e-03,  ssr = 4.4220e-02,  rl2s = 1.3744e-03, pde = 4.4088e-05,reg = 1.9784e+01
# iter. = 00302,  time = 000s,  loss = 1.1220e-03,  ssr = 4.4455e-02,  rl2s = 1.0776e-03, pde = 4.4322e-05,reg = 1.9783e+01
# iter. = 00303,  time = 000s,  loss = 1.6018e-04,  ssr = 4.5274e-02,  rl2s = 1.1504e-04, pde = 4.5139e-05,reg = 1.9780e+01
# iter. = 00304,  time = 000s,  loss = 1.4800e-03,  ssr = 4.6584e-02,  rl2s = 1.4336e-03, pde = 4.6444e-05,reg = 1.9779e+01
# iter. = 00305,  time = 000s,  loss = 2.1195e-03,  ssr = 4.7133e-02,  rl2s = 2.0725e-03, pde = 4.6992e-05,reg = 1.9779e+01
# iter. = 00306,  time = 000s,  loss = 1.9328e-03,  ssr = 4.6972e-02,  rl2s = 1.8860e-03, pde = 4.6831e-05,reg = 1.9780e+01
# iter. = 00307,  time = 000s,  loss = 1.0245e-03,  ssr = 4.6191e-02,  rl2s = 9.7847e-04, pde = 4.6052e-05,reg = 1.9782e+01
# iter. = 00308,  time = 000s,  loss = 5.7495e-04,  ssr = 4.4902e-02,  rl2s = 5.3018e-04, pde = 4.4767e-05,reg = 1.9783e+01
# iter. = 00309,  time = 000s,  loss = 1.2206e-03,  ssr = 4.4364e-02,  rl2s = 1.1764e-03, pde = 4.4232e-05,reg = 1.9783e+01
# iter. = 00310,  time = 000s,  loss = 1.1387e-03,  ssr = 4.4461e-02,  rl2s = 1.0944e-03, pde = 4.4328e-05,reg = 1.9781e+01
# iter. = 00311,  time = 000s,  loss = 4.1185e-04,  ssr = 4.5119e-02,  rl2s = 3.6686e-04, pde = 4.4984e-05,reg = 1.9779e+01
# iter. = 00312,  time = 000s,  loss = 1.0102e-03,  ssr = 4.6294e-02,  rl2s = 9.6401e-04, pde = 4.6156e-05,reg = 1.9779e+01
# iter. = 00313,  time = 000s,  loss = 1.5204e-03,  ssr = 4.6776e-02,  rl2s = 1.4738e-03, pde = 4.6636e-05,reg = 1.9779e+01
# iter. = 00314,  time = 000s,  loss = 1.2853e-03,  ssr = 4.6622e-02,  rl2s = 1.2388e-03, pde = 4.6483e-05,reg = 1.9780e+01
# iter. = 00315,  time = 000s,  loss = 4.0445e-04,  ssr = 4.5922e-02,  rl2s = 3.5867e-04, pde = 4.5784e-05,reg = 1.9782e+01
# iter. = 00316,  time = 000s,  loss = 1.1029e-03,  ssr = 4.4784e-02,  rl2s = 1.0583e-03, pde = 4.4650e-05,reg = 1.9782e+01
# iter. = 00317,  time = 000s,  loss = 1.7261e-03,  ssr = 4.4296e-02,  rl2s = 1.6819e-03, pde = 4.4163e-05,reg = 1.9782e+01
# iter. = 00318,  time = 000s,  loss = 1.6821e-03,  ssr = 4.4352e-02,  rl2s = 1.6379e-03, pde = 4.4220e-05,reg = 1.9781e+01
# iter. = 00319,  time = 000s,  loss = 1.0476e-03,  ssr = 4.4889e-02,  rl2s = 1.0028e-03, pde = 4.4755e-05,reg = 1.9779e+01
# iter. = 00320,  time = 000s,  loss = 2.3305e-04,  ssr = 4.5874e-02,  rl2s = 1.8731e-04, pde = 4.5736e-05,reg = 1.9778e+01
# iter. = 00321,  time = 000s,  loss = 6.9789e-04,  ssr = 4.6275e-02,  rl2s = 6.5175e-04, pde = 4.6137e-05,reg = 1.9778e+01
# iter. = 00322,  time = 000s,  loss = 4.9706e-04,  ssr = 4.6124e-02,  rl2s = 4.5107e-04, pde = 4.5986e-05,reg = 1.9779e+01
# iter. = 00323,  time = 000s,  loss = 3.8554e-04,  ssr = 4.5495e-02,  rl2s = 3.4018e-04, pde = 4.5359e-05,reg = 1.9779e+01
# iter. = 00324,  time = 000s,  loss = 4.9464e-04,  ssr = 4.5407e-02,  rl2s = 4.4937e-04, pde = 4.5272e-05,reg = 1.9779e+01
# iter. = 00325,  time = 000s,  loss = 1.0976e-04,  ssr = 4.5796e-02,  rl2s = 6.4099e-05, pde = 4.5659e-05,reg = 1.9778e+01
# iter. = 00326,  time = 000s,  loss = 1.8756e-04,  ssr = 4.5862e-02,  rl2s = 1.4183e-04, pde = 4.5725e-05,reg = 1.9779e+01
# iter. = 00327,  time = 000s,  loss = 3.7488e-04,  ssr = 4.5476e-02,  rl2s = 3.2954e-04, pde = 4.5339e-05,reg = 1.9778e+01
# iter. = 00328,  time = 000s,  loss = 2.2210e-04,  ssr = 4.5587e-02,  rl2s = 1.7665e-04, pde = 4.5450e-05,reg = 1.9777e+01
# iter. = 00329,  time = 000s,  loss = 5.6536e-04,  ssr = 4.6129e-02,  rl2s = 5.1937e-04, pde = 4.5991e-05,reg = 1.9777e+01
# iter. = 00330,  time = 000s,  loss = 6.0659e-04,  ssr = 4.6139e-02,  rl2s = 5.6059e-04, pde = 4.6001e-05,reg = 1.9778e+01
# iter. = 00331,  time = 000s,  loss = 1.0537e-04,  ssr = 4.5676e-02,  rl2s = 5.9836e-05, pde = 4.5539e-05,reg = 1.9779e+01
# iter. = 00332,  time = 000s,  loss = 7.5179e-04,  ssr = 4.5041e-02,  rl2s = 7.0688e-04, pde = 4.4906e-05,reg = 1.9779e+01
# iter. = 00333,  time = 000s,  loss = 8.6660e-04,  ssr = 4.4925e-02,  rl2s = 8.2181e-04, pde = 4.4790e-05,reg = 1.9778e+01
# iter. = 00334,  time = 000s,  loss = 4.4224e-04,  ssr = 4.5264e-02,  rl2s = 3.9711e-04, pde = 4.5129e-05,reg = 1.9777e+01
# iter. = 00335,  time = 000s,  loss = 5.6972e-04,  ssr = 4.6017e-02,  rl2s = 5.2384e-04, pde = 4.5879e-05,reg = 1.9776e+01
# iter. = 00336,  time = 000s,  loss = 8.5059e-04,  ssr = 4.6236e-02,  rl2s = 8.0449e-04, pde = 4.6097e-05,reg = 1.9777e+01
# iter. = 00337,  time = 000s,  loss = 5.6180e-04,  ssr = 4.5969e-02,  rl2s = 5.1597e-04, pde = 4.5831e-05,reg = 1.9778e+01
# iter. = 00338,  time = 000s,  loss = 3.1811e-04,  ssr = 4.5284e-02,  rl2s = 2.7296e-04, pde = 4.5149e-05,reg = 1.9778e+01
# iter. = 00339,  time = 000s,  loss = 5.0455e-04,  ssr = 4.5108e-02,  rl2s = 4.5957e-04, pde = 4.4973e-05,reg = 1.9777e+01
# iter. = 00340,  time = 000s,  loss = 1.7935e-04,  ssr = 4.5381e-02,  rl2s = 1.3411e-04, pde = 4.5245e-05,reg = 1.9776e+01
# iter. = 00341,  time = 000s,  loss = 6.9087e-04,  ssr = 4.6027e-02,  rl2s = 6.4498e-04, pde = 4.5889e-05,reg = 1.9776e+01
# iter. = 00342,  time = 000s,  loss = 8.6691e-04,  ssr = 4.6165e-02,  rl2s = 8.2089e-04, pde = 4.6026e-05,reg = 1.9776e+01
# iter. = 00343,  time = 000s,  loss = 5.1720e-04,  ssr = 4.5846e-02,  rl2s = 4.7149e-04, pde = 4.5709e-05,reg = 1.9777e+01
# iter. = 00344,  time = 000s,  loss = 3.8183e-04,  ssr = 4.5137e-02,  rl2s = 3.3683e-04, pde = 4.5002e-05,reg = 1.9778e+01
# iter. = 00345,  time = 000s,  loss = 6.1474e-04,  ssr = 4.4925e-02,  rl2s = 5.6995e-04, pde = 4.4790e-05,reg = 1.9777e+01
# iter. = 00346,  time = 000s,  loss = 3.5679e-04,  ssr = 4.5146e-02,  rl2s = 3.1178e-04, pde = 4.5011e-05,reg = 1.9776e+01
# iter. = 00347,  time = 000s,  loss = 4.4051e-04,  ssr = 4.5751e-02,  rl2s = 3.9489e-04, pde = 4.5614e-05,reg = 1.9776e+01
# iter. = 00348,  time = 000s,  loss = 5.9372e-04,  ssr = 4.5879e-02,  rl2s = 5.4798e-04, pde = 4.5742e-05,reg = 1.9776e+01
# iter. = 00349,  time = 000s,  loss = 2.6449e-04,  ssr = 4.5580e-02,  rl2s = 2.1905e-04, pde = 4.5444e-05,reg = 1.9777e+01
# iter. = 00350,  time = 000s,  loss = 5.7461e-04,  ssr = 4.4923e-02,  rl2s = 5.2983e-04, pde = 4.4789e-05,reg = 1.9777e+01
# iter. = 00351,  time = 000s,  loss = 7.8454e-04,  ssr = 4.4735e-02,  rl2s = 7.3994e-04, pde = 4.4601e-05,reg = 1.9777e+01
# iter. = 00352,  time = 000s,  loss = 5.3643e-04,  ssr = 4.4952e-02,  rl2s = 4.9161e-04, pde = 4.4818e-05,reg = 1.9776e+01
# iter. = 00353,  time = 000s,  loss = 2.2363e-04,  ssr = 4.5532e-02,  rl2s = 1.7823e-04, pde = 4.5396e-05,reg = 1.9776e+01
# iter. = 00354,  time = 000s,  loss = 3.8802e-04,  ssr = 4.5678e-02,  rl2s = 3.4248e-04, pde = 4.5541e-05,reg = 1.9776e+01
# iter. = 00355,  time = 000s,  loss = 1.2134e-04,  ssr = 4.5425e-02,  rl2s = 7.6051e-05, pde = 4.5289e-05,reg = 1.9777e+01
# iter. = 00356,  time = 000s,  loss = 5.5353e-04,  ssr = 4.4923e-02,  rl2s = 5.0874e-04, pde = 4.4789e-05,reg = 1.9777e+01
# iter. = 00357,  time = 000s,  loss = 6.3626e-04,  ssr = 4.4845e-02,  rl2s = 5.9155e-04, pde = 4.4711e-05,reg = 1.9776e+01
# iter. = 00358,  time = 000s,  loss = 3.0431e-04,  ssr = 4.5137e-02,  rl2s = 2.5931e-04, pde = 4.5002e-05,reg = 1.9775e+01
# iter. = 00359,  time = 000s,  loss = 4.9894e-04,  ssr = 4.5755e-02,  rl2s = 4.5332e-04, pde = 4.5618e-05,reg = 1.9775e+01
# iter. = 00360,  time = 000s,  loss = 7.1617e-04,  ssr = 4.5945e-02,  rl2s = 6.7036e-04, pde = 4.5807e-05,reg = 1.9775e+01
# iter. = 00361,  time = 000s,  loss = 4.9975e-04,  ssr = 4.5750e-02,  rl2s = 4.5413e-04, pde = 4.5613e-05,reg = 1.9776e+01
# iter. = 00362,  time = 000s,  loss = 1.9537e-04,  ssr = 4.5225e-02,  rl2s = 1.5028e-04, pde = 4.5090e-05,reg = 1.9776e+01
# iter. = 00363,  time = 000s,  loss = 3.4688e-04,  ssr = 4.5084e-02,  rl2s = 3.0193e-04, pde = 4.4949e-05,reg = 1.9776e+01
# iter. = 00364,  time = 000s,  loss = 1.2247e-04,  ssr = 4.5292e-02,  rl2s = 7.7313e-05, pde = 4.5156e-05,reg = 1.9775e+01
# iter. = 00365,  time = 000s,  loss = 4.9045e-04,  ssr = 4.5726e-02,  rl2s = 4.4486e-04, pde = 4.5589e-05,reg = 1.9775e+01
# iter. = 00366,  time = 000s,  loss = 5.5269e-04,  ssr = 4.5773e-02,  rl2s = 5.0705e-04, pde = 4.5637e-05,reg = 1.9775e+01
# iter. = 00367,  time = 000s,  loss = 2.3440e-04,  ssr = 4.5480e-02,  rl2s = 1.8905e-04, pde = 4.5344e-05,reg = 1.9776e+01
# iter. = 00368,  time = 000s,  loss = 5.0623e-04,  ssr = 4.4904e-02,  rl2s = 4.6146e-04, pde = 4.4770e-05,reg = 1.9776e+01
# iter. = 00369,  time = 000s,  loss = 7.1382e-04,  ssr = 4.4715e-02,  rl2s = 6.6924e-04, pde = 4.4581e-05,reg = 1.9776e+01
# iter. = 00370,  time = 000s,  loss = 5.4881e-04,  ssr = 4.4860e-02,  rl2s = 5.0408e-04, pde = 4.4725e-05,reg = 1.9775e+01
# iter. = 00371,  time = 000s,  loss = 9.7502e-05,  ssr = 4.5300e-02,  rl2s = 5.2337e-05, pde = 4.5165e-05,reg = 1.9775e+01
# iter. = 00372,  time = 000s,  loss = 5.2001e-04,  ssr = 4.5720e-02,  rl2s = 4.7443e-04, pde = 4.5583e-05,reg = 1.9774e+01
# iter. = 00373,  time = 000s,  loss = 5.9417e-04,  ssr = 4.5782e-02,  rl2s = 5.4853e-04, pde = 4.5645e-05,reg = 1.9775e+01
# iter. = 00374,  time = 000s,  loss = 3.1661e-04,  ssr = 4.5528e-02,  rl2s = 2.7122e-04, pde = 4.5392e-05,reg = 1.9776e+01
# iter. = 00375,  time = 000s,  loss = 3.6205e-04,  ssr = 4.5008e-02,  rl2s = 3.1718e-04, pde = 4.4874e-05,reg = 1.9776e+01
# iter. = 00376,  time = 000s,  loss = 5.4735e-04,  ssr = 4.4839e-02,  rl2s = 5.0264e-04, pde = 4.4705e-05,reg = 1.9775e+01
# iter. = 00377,  time = 000s,  loss = 3.9402e-04,  ssr = 4.4974e-02,  rl2s = 3.4918e-04, pde = 4.4840e-05,reg = 1.9775e+01
# iter. = 00378,  time = 000s,  loss = 1.6647e-04,  ssr = 4.5378e-02,  rl2s = 1.2122e-04, pde = 4.5242e-05,reg = 1.9775e+01
# iter. = 00379,  time = 000s,  loss = 2.7689e-04,  ssr = 4.5477e-02,  rl2s = 2.3155e-04, pde = 4.5341e-05,reg = 1.9775e+01
# iter. = 00380,  time = 000s,  loss = 1.0111e-04,  ssr = 4.5288e-02,  rl2s = 5.5962e-05, pde = 4.5152e-05,reg = 1.9775e+01
# iter. = 00381,  time = 000s,  loss = 3.2400e-04,  ssr = 4.5015e-02,  rl2s = 2.7912e-04, pde = 4.4881e-05,reg = 1.9775e+01
# iter. = 00382,  time = 000s,  loss = 2.8834e-04,  ssr = 4.5039e-02,  rl2s = 2.4344e-04, pde = 4.4905e-05,reg = 1.9775e+01
# iter. = 00383,  time = 000s,  loss = 1.4649e-04,  ssr = 4.5322e-02,  rl2s = 1.0130e-04, pde = 4.5186e-05,reg = 1.9775e+01
# iter. = 00384,  time = 000s,  loss = 1.7617e-04,  ssr = 4.5340e-02,  rl2s = 1.3096e-04, pde = 4.5204e-05,reg = 1.9775e+01
# iter. = 00385,  time = 000s,  loss = 1.7531e-04,  ssr = 4.5112e-02,  rl2s = 1.3034e-04, pde = 4.4977e-05,reg = 1.9775e+01
# iter. = 00386,  time = 000s,  loss = 1.3124e-04,  ssr = 4.5144e-02,  rl2s = 8.6234e-05, pde = 4.5009e-05,reg = 1.9774e+01
# iter. = 00387,  time = 000s,  loss = 2.5425e-04,  ssr = 4.5375e-02,  rl2s = 2.0901e-04, pde = 4.5239e-05,reg = 1.9774e+01
# iter. = 00388,  time = 000s,  loss = 2.2342e-04,  ssr = 4.5331e-02,  rl2s = 1.7822e-04, pde = 4.5195e-05,reg = 1.9775e+01
# iter. = 00389,  time = 000s,  loss = 1.7779e-04,  ssr = 4.5050e-02,  rl2s = 1.3287e-04, pde = 4.4915e-05,reg = 1.9775e+01
# iter. = 00390,  time = 000s,  loss = 1.8754e-04,  ssr = 4.5025e-02,  rl2s = 1.4265e-04, pde = 4.4891e-05,reg = 1.9774e+01
# iter. = 00391,  time = 000s,  loss = 1.6272e-04,  ssr = 4.5229e-02,  rl2s = 1.1763e-04, pde = 4.5093e-05,reg = 1.9774e+01
# iter. = 00392,  time = 000s,  loss = 1.4072e-04,  ssr = 4.5189e-02,  rl2s = 9.5663e-05, pde = 4.5054e-05,reg = 1.9775e+01
# iter. = 00393,  time = 000s,  loss = 2.1262e-04,  ssr = 4.4952e-02,  rl2s = 1.6781e-04, pde = 4.4818e-05,reg = 1.9775e+01
# iter. = 00394,  time = 000s,  loss = 1.8575e-04,  ssr = 4.4963e-02,  rl2s = 1.4092e-04, pde = 4.4828e-05,reg = 1.9774e+01
# iter. = 00395,  time = 000s,  loss = 1.8181e-04,  ssr = 4.5185e-02,  rl2s = 1.3676e-04, pde = 4.5050e-05,reg = 1.9774e+01
# iter. = 00396,  time = 000s,  loss = 1.8112e-04,  ssr = 4.5168e-02,  rl2s = 1.3609e-04, pde = 4.5033e-05,reg = 1.9775e+01
# iter. = 00397,  time = 000s,  loss = 1.5722e-04,  ssr = 4.4942e-02,  rl2s = 1.1241e-04, pde = 4.4808e-05,reg = 1.9775e+01
# iter. = 00398,  time = 000s,  loss = 1.4728e-04,  ssr = 4.4937e-02,  rl2s = 1.0248e-04, pde = 4.4803e-05,reg = 1.9774e+01
# iter. = 00399,  time = 000s,  loss = 1.7893e-04,  ssr = 4.5120e-02,  rl2s = 1.3394e-04, pde = 4.4985e-05,reg = 1.9774e+01
# iter. = 00400,  time = 000s,  loss = 1.5545e-04,  ssr = 4.5079e-02,  rl2s = 1.1051e-04, pde = 4.4944e-05,reg = 1.9775e+01
# iter. = 00401,  time = 000s,  loss = 1.8096e-04,  ssr = 4.4852e-02,  rl2s = 1.3624e-04, pde = 4.4718e-05,reg = 1.9775e+01
# iter. = 00402,  time = 000s,  loss = 1.7394e-04,  ssr = 4.4844e-02,  rl2s = 1.2923e-04, pde = 4.4710e-05,reg = 1.9774e+01
# iter. = 00403,  time = 000s,  loss = 1.4730e-04,  ssr = 4.5024e-02,  rl2s = 1.0241e-04, pde = 4.4890e-05,reg = 1.9774e+01
# iter. = 00404,  time = 000s,  loss = 1.4452e-04,  ssr = 4.5005e-02,  rl2s = 9.9646e-05, pde = 4.4871e-05,reg = 1.9775e+01
# iter. = 00405,  time = 000s,  loss = 1.5618e-04,  ssr = 4.4815e-02,  rl2s = 1.1150e-04, pde = 4.4681e-05,reg = 1.9774e+01
# iter. = 00406,  time = 000s,  loss = 1.3825e-04,  ssr = 4.4819e-02,  rl2s = 9.3569e-05, pde = 4.4685e-05,reg = 1.9774e+01
# iter. = 00407,  time = 000s,  loss = 1.6642e-04,  ssr = 4.4984e-02,  rl2s = 1.2157e-04, pde = 4.4849e-05,reg = 1.9774e+01
# iter. = 00408,  time = 000s,  loss = 1.5236e-04,  ssr = 4.4953e-02,  rl2s = 1.0754e-04, pde = 4.4818e-05,reg = 1.9774e+01
# iter. = 00409,  time = 000s,  loss = 1.5053e-04,  ssr = 4.4758e-02,  rl2s = 1.0591e-04, pde = 4.4624e-05,reg = 1.9774e+01
# iter. = 00410,  time = 000s,  loss = 1.4790e-04,  ssr = 4.4746e-02,  rl2s = 1.0328e-04, pde = 4.4612e-05,reg = 1.9774e+01
# iter. = 00411,  time = 000s,  loss = 1.3730e-04,  ssr = 4.4892e-02,  rl2s = 9.2541e-05, pde = 4.4758e-05,reg = 1.9774e+01
# iter. = 00412,  time = 000s,  loss = 1.3099e-04,  ssr = 4.4870e-02,  rl2s = 8.6250e-05, pde = 4.4736e-05,reg = 1.9774e+01
# iter. = 00413,  time = 000s,  loss = 1.4318e-04,  ssr = 4.4706e-02,  rl2s = 9.8609e-05, pde = 4.4573e-05,reg = 1.9774e+01
# iter. = 00414,  time = 000s,  loss = 1.2936e-04,  ssr = 4.4708e-02,  rl2s = 8.4790e-05, pde = 4.4574e-05,reg = 1.9774e+01
# iter. = 00415,  time = 000s,  loss = 1.4526e-04,  ssr = 4.4844e-02,  rl2s = 1.0055e-04, pde = 4.4709e-05,reg = 1.9774e+01
# iter. = 00416,  time = 000s,  loss = 1.3479e-04,  ssr = 4.4817e-02,  rl2s = 9.0105e-05, pde = 4.4683e-05,reg = 1.9774e+01
# iter. = 00417,  time = 000s,  loss = 1.3600e-04,  ssr = 4.4656e-02,  rl2s = 9.1473e-05, pde = 4.4522e-05,reg = 1.9774e+01
# iter. = 00418,  time = 000s,  loss = 1.3254e-04,  ssr = 4.4646e-02,  rl2s = 8.8026e-05, pde = 4.4513e-05,reg = 1.9774e+01
# iter. = 00419,  time = 000s,  loss = 1.2617e-04,  ssr = 4.4765e-02,  rl2s = 8.1536e-05, pde = 4.4631e-05,reg = 1.9774e+01
# iter. = 00420,  time = 000s,  loss = 1.2279e-04,  ssr = 4.4746e-02,  rl2s = 7.8180e-05, pde = 4.4612e-05,reg = 1.9774e+01
# iter. = 00421,  time = 000s,  loss = 1.2511e-04,  ssr = 4.4613e-02,  rl2s = 8.0630e-05, pde = 4.4479e-05,reg = 1.9774e+01
# iter. = 00422,  time = 000s,  loss = 1.1763e-04,  ssr = 4.4609e-02,  rl2s = 7.3152e-05, pde = 4.4476e-05,reg = 1.9774e+01
# iter. = 00423,  time = 000s,  loss = 1.2542e-04,  ssr = 4.4709e-02,  rl2s = 8.0846e-05, pde = 4.4575e-05,reg = 1.9774e+01
# iter. = 00424,  time = 000s,  loss = 1.1667e-04,  ssr = 4.4683e-02,  rl2s = 7.2118e-05, pde = 4.4550e-05,reg = 1.9774e+01
# iter. = 00425,  time = 000s,  loss = 1.2338e-04,  ssr = 4.4560e-02,  rl2s = 7.8950e-05, pde = 4.4426e-05,reg = 1.9774e+01
# iter. = 00426,  time = 000s,  loss = 1.1733e-04,  ssr = 4.4555e-02,  rl2s = 7.2908e-05, pde = 4.4422e-05,reg = 1.9774e+01
# iter. = 00427,  time = 000s,  loss = 1.1762e-04,  ssr = 4.4645e-02,  rl2s = 7.3109e-05, pde = 4.4512e-05,reg = 1.9774e+01
# iter. = 00428,  time = 000s,  loss = 1.1503e-04,  ssr = 4.4628e-02,  rl2s = 7.0534e-05, pde = 4.4495e-05,reg = 1.9774e+01
# iter. = 00429,  time = 000s,  loss = 1.1229e-04,  ssr = 4.4522e-02,  rl2s = 6.7903e-05, pde = 4.4389e-05,reg = 1.9774e+01
# iter. = 00430,  time = 000s,  loss = 1.1136e-04,  ssr = 4.4511e-02,  rl2s = 6.6981e-05, pde = 4.4378e-05,reg = 1.9774e+01
# iter. = 00431,  time = 000s,  loss = 1.0831e-04,  ssr = 4.4580e-02,  rl2s = 6.3859e-05, pde = 4.4446e-05,reg = 1.9774e+01
# iter. = 00432,  time = 000s,  loss = 1.0764e-04,  ssr = 4.4566e-02,  rl2s = 6.3207e-05, pde = 4.4432e-05,reg = 1.9774e+01
# iter. = 00433,  time = 000s,  loss = 1.0566e-04,  ssr = 4.4482e-02,  rl2s = 6.1309e-05, pde = 4.4349e-05,reg = 1.9774e+01
# iter. = 00434,  time = 000s,  loss = 1.0498e-04,  ssr = 4.4471e-02,  rl2s = 6.0646e-05, pde = 4.4338e-05,reg = 1.9774e+01
# iter. = 00435,  time = 000s,  loss = 1.0329e-04,  ssr = 4.4520e-02,  rl2s = 5.8907e-05, pde = 4.4387e-05,reg = 1.9774e+01
# iter. = 00436,  time = 000s,  loss = 1.0307e-04,  ssr = 4.4507e-02,  rl2s = 5.8698e-05, pde = 4.4374e-05,reg = 1.9774e+01
# iter. = 00437,  time = 000s,  loss = 1.0111e-04,  ssr = 4.4441e-02,  rl2s = 5.6804e-05, pde = 4.4308e-05,reg = 1.9774e+01
# iter. = 00438,  time = 000s,  loss = 1.0179e-04,  ssr = 4.4428e-02,  rl2s = 5.7499e-05, pde = 4.4295e-05,reg = 1.9774e+01
# iter. = 00439,  time = 000s,  loss = 9.9008e-05,  ssr = 4.4461e-02,  rl2s = 5.4680e-05, pde = 4.4328e-05,reg = 1.9774e+01
# iter. = 00440,  time = 000s,  loss = 1.0084e-04,  ssr = 4.4454e-02,  rl2s = 5.6523e-05, pde = 4.4321e-05,reg = 1.9774e+01
# iter. = 00441,  time = 000s,  loss = 9.7273e-05,  ssr = 4.4405e-02,  rl2s = 5.3001e-05, pde = 4.4272e-05,reg = 1.9774e+01
# iter. = 00442,  time = 000s,  loss = 1.0011e-04,  ssr = 4.4384e-02,  rl2s = 5.5861e-05, pde = 4.4251e-05,reg = 1.9774e+01
# iter. = 00443,  time = 000s,  loss = 9.6101e-05,  ssr = 4.4401e-02,  rl2s = 5.1832e-05, pde = 4.4268e-05,reg = 1.9774e+01
# iter. = 00444,  time = 000s,  loss = 9.9407e-05,  ssr = 4.4404e-02,  rl2s = 5.5135e-05, pde = 4.4271e-05,reg = 1.9774e+01
# iter. = 00445,  time = 000s,  loss = 9.5724e-05,  ssr = 4.4373e-02,  rl2s = 5.1483e-05, pde = 4.4240e-05,reg = 1.9774e+01
# iter. = 00446,  time = 000s,  loss = 9.8492e-05,  ssr = 4.4343e-02,  rl2s = 5.4281e-05, pde = 4.4211e-05,reg = 1.9774e+01
# iter. = 00447,  time = 000s,  loss = 9.6108e-05,  ssr = 4.4344e-02,  rl2s = 5.1897e-05, pde = 4.4211e-05,reg = 1.9774e+01
# iter. = 00448,  time = 000s,  loss = 9.7245e-05,  ssr = 4.4354e-02,  rl2s = 5.3024e-05, pde = 4.4221e-05,reg = 1.9774e+01
# iter. = 00449,  time = 000s,  loss = 9.6808e-05,  ssr = 4.4341e-02,  rl2s = 5.2599e-05, pde = 4.4209e-05,reg = 1.9774e+01
# iter. = 00450,  time = 000s,  loss = 9.6035e-05,  ssr = 4.4313e-02,  rl2s = 5.1854e-05, pde = 4.4181e-05,reg = 1.9774e+01
# iter. = 00451,  time = 000s,  loss = 9.7123e-05,  ssr = 4.4297e-02,  rl2s = 5.2958e-05, pde = 4.4164e-05,reg = 1.9774e+01
# iter. = 00452,  time = 000s,  loss = 9.5608e-05,  ssr = 4.4299e-02,  rl2s = 5.1441e-05, pde = 4.4167e-05,reg = 1.9774e+01
# iter. = 00453,  time = 000s,  loss = 9.6631e-05,  ssr = 4.4302e-02,  rl2s = 5.2462e-05, pde = 4.4170e-05,reg = 1.9774e+01
# iter. = 00454,  time = 000s,  loss = 9.6049e-05,  ssr = 4.4289e-02,  rl2s = 5.1892e-05, pde = 4.4157e-05,reg = 1.9774e+01
# iter. = 00455,  time = 000s,  loss = 9.5771e-05,  ssr = 4.4268e-02,  rl2s = 5.1635e-05, pde = 4.4136e-05,reg = 1.9774e+01
# iter. = 00456,  time = 000s,  loss = 9.6362e-05,  ssr = 4.4255e-02,  rl2s = 5.2239e-05, pde = 4.4122e-05,reg = 1.9774e+01
# iter. = 00457,  time = 000s,  loss = 9.5578e-05,  ssr = 4.4254e-02,  rl2s = 5.1457e-05, pde = 4.4121e-05,reg = 1.9774e+01
# iter. = 00458,  time = 000s,  loss = 9.5900e-05,  ssr = 4.4255e-02,  rl2s = 5.1777e-05, pde = 4.4122e-05,reg = 1.9774e+01
# iter. = 00459,  time = 000s,  loss = 9.5960e-05,  ssr = 4.4247e-02,  rl2s = 5.1845e-05, pde = 4.4115e-05,reg = 1.9774e+01
# iter. = 00460,  time = 000s,  loss = 9.5483e-05,  ssr = 4.4232e-02,  rl2s = 5.1383e-05, pde = 4.4100e-05,reg = 1.9774e+01
# iter. = 00461,  time = 000s,  loss = 9.5819e-05,  ssr = 4.4218e-02,  rl2s = 5.1733e-05, pde = 4.4086e-05,reg = 1.9774e+01
# iter. = 00462,  time = 000s,  loss = 9.5725e-05,  ssr = 4.4212e-02,  rl2s = 5.1646e-05, pde = 4.4080e-05,reg = 1.9774e+01
# iter. = 00463,  time = 000s,  loss = 9.5449e-05,  ssr = 4.4211e-02,  rl2s = 5.1370e-05, pde = 4.4079e-05,reg = 1.9774e+01
# iter. = 00464,  time = 000s,  loss = 9.5679e-05,  ssr = 4.4209e-02,  rl2s = 5.1602e-05, pde = 4.4077e-05,reg = 1.9774e+01
# iter. = 00465,  time = 000s,  loss = 9.5613e-05,  ssr = 4.4202e-02,  rl2s = 5.1543e-05, pde = 4.4070e-05,reg = 1.9774e+01
# iter. = 00466,  time = 000s,  loss = 9.5414e-05,  ssr = 4.4191e-02,  rl2s = 5.1355e-05, pde = 4.4059e-05,reg = 1.9774e+01
# iter. = 00467,  time = 000s,  loss = 9.5543e-05,  ssr = 4.4181e-02,  rl2s = 5.1495e-05, pde = 4.4049e-05,reg = 1.9774e+01
# iter. = 00468,  time = 000s,  loss = 9.5551e-05,  ssr = 4.4175e-02,  rl2s = 5.1509e-05, pde = 4.4043e-05,reg = 1.9774e+01
# iter. = 00469,  time = 000s,  loss = 9.5395e-05,  ssr = 4.4172e-02,  rl2s = 5.1355e-05, pde = 4.4040e-05,reg = 1.9774e+01
# iter. = 00470,  time = 000s,  loss = 9.5426e-05,  ssr = 4.4170e-02,  rl2s = 5.1388e-05, pde = 4.4038e-05,reg = 1.9774e+01
# iter. = 00471,  time = 000s,  loss = 9.5488e-05,  ssr = 4.4166e-02,  rl2s = 5.1454e-05, pde = 4.4034e-05,reg = 1.9774e+01
# iter. = 00472,  time = 000s,  loss = 9.5401e-05,  ssr = 4.4160e-02,  rl2s = 5.1373e-05, pde = 4.4028e-05,reg = 1.9774e+01
# iter. = 00473,  time = 000s,  loss = 9.5351e-05,  ssr = 4.4152e-02,  rl2s = 5.1331e-05, pde = 4.4020e-05,reg = 1.9774e+01
# iter. = 00474,  time = 000s,  loss = 9.5402e-05,  ssr = 4.4145e-02,  rl2s = 5.1389e-05, pde = 4.4013e-05,reg = 1.9774e+01
# iter. = 00475,  time = 000s,  loss = 9.5400e-05,  ssr = 4.4140e-02,  rl2s = 5.1392e-05, pde = 4.4008e-05,reg = 1.9774e+01
# iter. = 00476,  time = 000s,  loss = 9.5338e-05,  ssr = 4.4138e-02,  rl2s = 5.1332e-05, pde = 4.4006e-05,reg = 1.9774e+01
# iter. = 00477,  time = 000s,  loss = 9.5324e-05,  ssr = 4.4135e-02,  rl2s = 5.1321e-05, pde = 4.4003e-05,reg = 1.9774e+01
# iter. = 00478,  time = 000s,  loss = 9.5352e-05,  ssr = 4.4133e-02,  rl2s = 5.1352e-05, pde = 4.4001e-05,reg = 1.9774e+01
# iter. = 00479,  time = 000s,  loss = 9.5344e-05,  ssr = 4.4129e-02,  rl2s = 5.1347e-05, pde = 4.3997e-05,reg = 1.9774e+01
# iter. = 00480,  time = 000s,  loss = 9.5306e-05,  ssr = 4.4124e-02,  rl2s = 5.1314e-05, pde = 4.3992e-05,reg = 1.9774e+01
# iter. = 00481,  time = 000s,  loss = 9.5294e-05,  ssr = 4.4119e-02,  rl2s = 5.1307e-05, pde = 4.3987e-05,reg = 1.9774e+01
# iter. = 00482,  time = 000s,  loss = 9.5307e-05,  ssr = 4.4114e-02,  rl2s = 5.1325e-05, pde = 4.3982e-05,reg = 1.9774e+01
# iter. = 00483,  time = 000s,  loss = 9.5306e-05,  ssr = 4.4110e-02,  rl2s = 5.1328e-05, pde = 4.3978e-05,reg = 1.9774e+01
# iter. = 00484,  time = 000s,  loss = 9.5285e-05,  ssr = 4.4108e-02,  rl2s = 5.1309e-05, pde = 4.3976e-05,reg = 1.9774e+01
# iter. = 00485,  time = 000s,  loss = 9.5269e-05,  ssr = 4.4106e-02,  rl2s = 5.1295e-05, pde = 4.3974e-05,reg = 1.9774e+01
# iter. = 00486,  time = 000s,  loss = 9.5270e-05,  ssr = 4.4104e-02,  rl2s = 5.1299e-05, pde = 4.3972e-05,reg = 1.9774e+01
# iter. = 00487,  time = 000s,  loss = 9.5274e-05,  ssr = 4.4101e-02,  rl2s = 5.1305e-05, pde = 4.3969e-05,reg = 1.9774e+01
# iter. = 00488,  time = 000s,  loss = 9.5266e-05,  ssr = 4.4098e-02,  rl2s = 5.1300e-05, pde = 4.3966e-05,reg = 1.9774e+01
# iter. = 00489,  time = 000s,  loss = 9.5252e-05,  ssr = 4.4095e-02,  rl2s = 5.1290e-05, pde = 4.3963e-05,reg = 1.9774e+01
# iter. = 00490,  time = 000s,  loss = 9.5245e-05,  ssr = 4.4091e-02,  rl2s = 5.1285e-05, pde = 4.3959e-05,reg = 1.9774e+01
# iter. = 00491,  time = 000s,  loss = 9.5244e-05,  ssr = 4.4088e-02,  rl2s = 5.1289e-05, pde = 4.3956e-05,reg = 1.9774e+01
# iter. = 00492,  time = 000s,  loss = 9.5244e-05,  ssr = 4.4085e-02,  rl2s = 5.1291e-05, pde = 4.3953e-05,reg = 1.9774e+01
# iter. = 00493,  time = 000s,  loss = 9.5238e-05,  ssr = 4.4083e-02,  rl2s = 5.1287e-05, pde = 4.3951e-05,reg = 1.9774e+01
# iter. = 00494,  time = 000s,  loss = 9.5229e-05,  ssr = 4.4080e-02,  rl2s = 5.1281e-05, pde = 4.3949e-05,reg = 1.9774e+01
# iter. = 00495,  time = 000s,  loss = 9.5223e-05,  ssr = 4.4079e-02,  rl2s = 5.1276e-05, pde = 4.3947e-05,reg = 1.9774e+01
# iter. = 00496,  time = 000s,  loss = 9.5221e-05,  ssr = 4.4077e-02,  rl2s = 5.1276e-05, pde = 4.3945e-05,reg = 1.9774e+01
# iter. = 00497,  time = 000s,  loss = 9.5219e-05,  ssr = 4.4074e-02,  rl2s = 5.1277e-05, pde = 4.3943e-05,reg = 1.9774e+01
# iter. = 00498,  time = 000s,  loss = 9.5215e-05,  ssr = 4.4072e-02,  rl2s = 5.1275e-05, pde = 4.3940e-05,reg = 1.9774e+01
# iter. = 00499,  time = 000s,  loss = 9.5209e-05,  ssr = 4.4069e-02,  rl2s = 5.1271e-05, pde = 4.3938e-05,reg = 1.9774e+01
# iter. = 00500,  time = 000s,  loss = 9.5203e-05,  ssr = 4.4067e-02,  rl2s = 5.1268e-05, pde = 4.3935e-05,reg = 1.9774e+01

# %%
# Extract iteration and Loss data from the 'store' array
iterations = store[:, 0]
loss_values = store[:, 2]  # Loss is the 3rd column (index 2)

# Create the scatter plot
plt.figure(figsize=(10, 6))
plt.plot(iterations[1:], loss_values[1:], label='Loss per Iteration', alpha=0.6)

# Add labels and title
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.yscale('log')
plt.title('Loss vs. Training Iterations')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Extract iteration and pde_loss data from the 'store' array
iterations = store[:, 0]
pde_loss_values = store[:, 4]  # pde_loss is the 5th column (index 4)

# Create the scatter plot for PDE loss
plt.figure(figsize=(10, 6))
plt.plot(iterations[1:], pde_loss_values[1:], label='PDE Loss per Iteration', alpha=0.6)

# Add labels and title
plt.xlabel('Iteration')
plt.ylabel('PDE Loss')
plt.yscale('log')
plt.title('PDE Loss vs. Training Iterations')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Generate learning rate values over iterations
lrs = lr_scheduler(jnp.arange(max_iters + 1))

# Plot the learning rate
plt.figure(figsize=(10, 6))
plt.plot(jnp.arange(max_iters + 1), lrs)
plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel('Learning Rate')
plt.title('Learning Rate Schedule')
plt.grid(True)
plt.show()

# %%
def eval_prediction(params):
  shaped_xvals = reac.xvals.reshape(reac.Nx, 1)
  pred, pre_act = model.apply(format_params_fn(params[:-1]), shaped_xvals)
  f, f_x, f_xx = jnp.split(pred, 3, axis=1)


  coeffs = gen_coeffs(y_steady, reac, oper)

  pde_A1 = coeffs[:,0].reshape(-1,1) * f_xx + coeffs[:,1].reshape(-1,1) * f_x
  bc_NH3_A = f[0]
  bc2_NH3_A = f_x[-1]
  A = jnp.vstack([pde_A1, bc_NH3_A, bc2_NH3_A])

  # Generate RHS

  reg = regularization_factor(params[-1]) #10**(nn.sigmoid(params[-1])*4 - 6)
  #jax.debug.print("reg: {r}", r = reg)

  # Generate RHS
  pde_b1 = -coeffs[:,2].reshape(-1,1)
  b = jnp.vstack([pde_b1, jnp.array(0.995), jnp.array(0.0)])
  #jax.debug.print("b: {b}", b = b)

  As, bs = reg*jnp.eye(A.shape[1]) + (A.T@A), A.T@b #this is least squares  (A.T@A)
  w_PI = solve(As, bs)
  pred1 = f @ w_PI

  return pred1, pre_act

# %%
pred1, pre_act = eval_prediction(params)


fig = plt.figure
shaped_xvals = reac.xvals.reshape(reac.Nx, 1)
plt.plot(shaped_xvals, pred1, label='NH3_prediction')
plt.plot(shaped_xvals, Y_NH3, linestyle = 'dashed', label='NH3_ground_truth')
plt.xlabel('reactor length (m)')
plt.ylabel('NH3 Concentration')
plt.legend()
plt.show()
# Out:
# (256,)
